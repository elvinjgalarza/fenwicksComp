# %% [markdown]
# <a href="https://colab.research.google.com/github/fenwickslab/fenwicks/blob/master/tutorials/tutorial5_flowers.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install -qq -U cufflinks

# %%
import tensorflow as tf
import os
import numpy as np

# %%
if tf.io.gfile.exists('./fenwicks'):
  tf.io.gfile.rmtree('./fenwicks')
# !git clone -q https://github.com/fenwickslab/fenwicks.git

import fenwicks as fw
# Out:
# <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script><script>requirejs.config({paths: { 'plotly': ['https://cdn.plot.ly/plotly-latest.min']},});if(!window._Plotly) {require(['plotly'],function(plotly) {window._Plotly=plotly;});}</script>
# <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script><script>requirejs.config({paths: { 'plotly': ['https://cdn.plot.ly/plotly-latest.min']},});if(!window._Plotly) {require(['plotly'],function(plotly) {window._Plotly=plotly;});}</script>
# <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script><script>requirejs.config({paths: { 'plotly': ['https://cdn.plot.ly/plotly-latest.min']},});if(!window._Plotly) {require(['plotly'],function(plotly) {window._Plotly=plotly;});}</script>

# %%
ROOT_DIR = 'gs://gs_colab'
PROJECT = 'tutorial5'
MODEL = "ResNet50" #@param ["InceptionResNetV2", "ResNet50", "ResNet50V2", "InceptionV3", "MobileNetV2", "Xception"]

BATCH_SIZE = 128 #@param ["64", "128", "256", "512"] {type:"raw"}
EPOCHS = 11 #@param {type:"slider", min:1, max:100, step:1}
LEARNING_RATE = 0.001 #@param ["0.001", "0.01"] {type:"raw"}
WARMUP = 0.05 #@param {type:"slider", min:0, max:0.5, step:0.05}
# Out:
#     <script src="/static/components/requirejs/require.js"></script>
#     <script>
#       requirejs.config({
#         paths: {
#           base: '/static/base',
#           plotly: 'https://cdn.plot.ly/plotly-1.47.1.min.js?noext',
#         },
#       });
#     </script>

# %%
fw.colab_utils.setup_gcs()
# Out:
#     <script src="/static/components/requirejs/require.js"></script>
#     <script>
#       requirejs.config({
#         paths: {
#           base: '/static/base',
#           plotly: 'https://cdn.plot.ly/plotly-1.47.1.min.js?noext',
#         },
#       });
#     </script>

# %%
data_dir, work_dir = fw.io.get_project_dirs(ROOT_DIR, PROJECT)
# Out:
#     <script src="/static/components/requirejs/require.js"></script>
#     <script>
#       requirejs.config({
#         paths: {
#           base: '/static/base',
#           plotly: 'https://cdn.plot.ly/plotly-1.47.1.min.js?noext',
#         },
#       });
#     </script>

# %%
base_model = fw.keras_models.get_model(MODEL, ROOT_DIR)
# Out:
#     <script src="/static/components/requirejs/require.js"></script>
#     <script>
#       requirejs.config({
#         paths: {
#           base: '/static/base',
#           plotly: 'https://cdn.plot.ly/plotly-1.47.1.min.js?noext',
#         },
#       });
#     </script>

# %%
data_dir_local = fw.datasets.untar_data(fw.datasets.URLs.FLOWER_PHOTOS, './flower_photos')
# Out:
#     <script src="/static/components/requirejs/require.js"></script>
#     <script>
#       requirejs.config({
#         paths: {
#           base: '/static/base',
#           plotly: 'https://cdn.plot.ly/plotly-1.47.1.min.js?noext',
#         },
#       });
#     </script>

# %%
data_dir_local = os.path.join(data_dir_local, 'flower_photos')
data_dir_local
# Out:
#     <script src="/static/components/requirejs/require.js"></script>
#     <script>
#       requirejs.config({
#         paths: {
#           base: '/static/base',
#           plotly: 'https://cdn.plot.ly/plotly-1.47.1.min.js?noext',
#         },
#       });
#     </script>
# './flower_photos/datasets/flower_photos'

# %%
data_fn = os.path.join(data_dir, 'all.tfrecord')

paths, y, labels = fw.data.data_dir_tfrecord(data_dir_local, data_fn, shuffle=True)
n_classes = len(labels)
n_all = len(y)
# Out:
#     <script src="/static/components/requirejs/require.js"></script>
#     <script>
#       requirejs.config({
#         paths: {
#           base: '/static/base',
#           plotly: 'https://cdn.plot.ly/plotly-1.47.1.min.js?noext',
#         },
#       });
#     </script>
# INFO:tensorflow:Output file already exists. Skipping.

# %%
fw.plt.plot_counts_pie(y, labels)
# Out:
#     <script src="/static/components/requirejs/require.js"></script>
#     <script>
#       requirejs.config({
#         paths: {
#           base: '/static/base',
#           plotly: 'https://cdn.plot.ly/plotly-1.47.1.min.js?noext',
#         },
#       });
#     </script>
# <div id="638d74ae-eeff-4810-a238-a8b956bc6dc4" style="height: 350px; width: 350px;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("638d74ae-eeff-4810-a238-a8b956bc6dc4", [{"hole": 0.2, "labels": ["dandelion", "tulips", "sunflowers", "roses", "daisy"], "marker": {"colors": ["rgba(255, 153, 51, 1.0)", "rgba(55, 128, 191, 1.0)", "rgba(50, 171, 96, 1.0)", "rgba(128, 0, 128, 1.0)", "rgba(219, 64, 82, 1.0)"]}, "name": "", "pull": 0.05, "values": [898, 799, 699, 641, 633], "type": "pie"}], {"height": 350, "margin": {"b": 0, "l": 50, "r": 0, "t": 0}, "width": 350}, {"showLink": true, "linkText": "Export to plot.ly", "plotlyServerURL": "https://plot.ly"})});</script>

# %%
fw.anim.show_image_files(paths)
# Out:
#     <script src="/static/components/requirejs/require.js"></script>
#     <script>
#       requirejs.config({
#         paths: {
#           base: '/static/base',
#           plotly: 'https://cdn.plot.ly/plotly-1.47.1.min.js?noext',
#         },
#       });
#     </script>
# <video width="216" height="216" controls autoplay loop>
#   <source type="video/mp4" src="...

# %%
def build_nn():
  base = base_model.model_func()
  base.trainable = False
  model = fw.Sequential()
  model.add(base)
  model.add(tf.keras.layers.Flatten())
  model.add(fw.layers.Classifier(n_classes))
  return model
# Out:
#     <script src="/static/components/requirejs/require.js"></script>
#     <script>
#       requirejs.config({
#         paths: {
#           base: '/static/base',
#           plotly: 'https://cdn.plot.ly/plotly-1.47.1.min.js?noext',
#         },
#       });
#     </script>

# %%
n_valid = n_all // 5 // 8 * 8
n_train = n_all - n_valid
steps_per_epoch = n_train // BATCH_SIZE
total_steps = steps_per_epoch * EPOCHS
warmup_steps = int(total_steps * WARMUP)
# Out:
#     <script src="/static/components/requirejs/require.js"></script>
#     <script>
#       requirejs.config({
#         paths: {
#           base: '/static/base',
#           plotly: 'https://cdn.plot.ly/plotly-1.47.1.min.js?noext',
#         },
#       });
#     </script>

# %%
cosine_decay = tf.train.cosine_decay_restarts
lr_func = fw.train.one_cycle_lr(LEARNING_RATE, total_steps, warmup_steps, cosine_decay)
fw.plt.plot_lr_func(lr_func, total_steps)
# Out:
#     <script src="/static/components/requirejs/require.js"></script>
#     <script>
#       requirejs.config({
#         paths: {
#           base: '/static/base',
#           plotly: 'https://cdn.plot.ly/plotly-1.47.1.min.js?noext',
#         },
#       });
#     </script>
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow/python/ops/control_flow_ops.py:423: colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.
# <div id="c2342adf-0bdf-4938-9ff2-bfa8c1165692" style="height: 350px; width: 350px;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("c

# Out:
#     <script src="/static/components/requirejs/require.js"></script>
#     <script>
#       requirejs.config({
#         paths: {
#           base: '/static/base',
#           plotly: 'https://cdn.plot.ly/plotly-1.47.1.min.js?noext',
#         },
#       });
#     </script>

# %%
def get_input_parser(training):
  h = w = base_model.img_size
  tfms = fw.transform.get_fastai_transforms(h, w, training=training, normalizer=base_model.normalizer)
  return fw.data.get_tfexample_image_parser(tfms)

parser_train = get_input_parser(True)
parser_eval = get_input_parser(False)
# Out:
#     <script src="/static/components/requirejs/require.js"></script>
#     <script>
#       requirejs.config({
#         paths: {
#           base: '/static/base',
#           plotly: 'https://cdn.plot.ly/plotly-1.47.1.min.js?noext',
#         },
#       });
#     </script>

# %%
est = fw.train.get_tpu_estimator(n_train // BATCH_SIZE, model_func, work_dir, 
  base_model.weight_dir, base_model.weight_vars, trn_bs=BATCH_SIZE, val_bs=n_valid)
# Out:
#     <script src="/static/components/requirejs/require.js"></script>
#     <script>
#       requirejs.config({
#         paths: {
#           base: '/static/base',
#           plotly: 'https://cdn.plot.ly/plotly-1.47.1.min.js?noext',
#         },
#       });
#     </script>
# WARNING:tensorflow:Estimator's model_fn (<function get_clf_model_func.<locals>.model_func at 0x7fdf029f0730>) includes params argument, but params are not passed to Estimator.
# INFO:tensorflow:Using config: {'_model_dir': 'gs://gs_colab/work/tutorial5/2019-05-16-15:44:07', '_tf_random_seed': None, '_save_summary_steps': 100, '_save_checkpoints_steps': None, '_save_checkpoints_secs': 600, '_session_config': allow_soft_placement: true
# cluster_def {
#   job {
#     name: "worker"
#     tasks {
#       key: 0
#       value: "10.73.202.122:8470"
#     }
#   }
# }
# , '_keep_checkpoint_max': 5, '_keep_checkpoint_every_n_hours': 10000, '_log_step_count_steps': None, '_train_distribute': None, '_device_fn': None, '_protocol': None, '_eval_distribute': None, '_experimental_distribute': None, '_service': None, '_cluster_spec': <tensorflow.python.training.server_lib.ClusterSpec object at 0x7fded79ab208>, '_task_type': 'worker', '_task_id': 0, '_global_id_in_cluster': 0, '_master': 'grpc://10.73.202.122:8470', '_evaluation_master': 'grpc://10.73.202.122:8470', '_is_chief': True, '_num_ps_replicas': 0, '_num_worker_replicas': 1, '_tpu_config': TPUConfig(iterations_per_loop=22, num_shards=None, num_cores_per_replica=None, per_host_input_for_training=3, tpu_job_name=None, initial_infeed_sleep_secs=None, input_partition_dims=None), '_cluster': <tensorflow.python.distribute.cluster_resolver.tpu_cluster_resolver.TPUClusterResolver object at 0x7fded79ab6a0>}
# INFO:tensorflow:_TPUContext: eval_on_tpu True

# %%
def train_eval_fold(val_fold):
  train_input_func = lambda params: fw.data.tfrecord_ds(data_fn, parser_train,
    params['batch_size'], n_folds=5, val_fold_idx = val_fold, training=True)
  valid_input_func = lambda params: fw.data.tfrecord_ds(data_fn, parser_eval, 
    params['batch_size'], n_folds=5, val_fold_idx = val_fold, training=False)

  est.train(train_input_func, steps=total_steps)
  result = est.evaluate(valid_input_func, steps=1)
  fw.io.create_clean_dir(work_dir)
  return result
# Out:
#     <script src="/static/components/requirejs/require.js"></script>
#     <script>
#       requirejs.config({
#         paths: {
#           base: '/static/base',
#           plotly: 'https://cdn.plot.ly/plotly-1.47.1.min.js?noext',
#         },
#       });
#     </script>

# %%
result = []
result.append(train_eval_fold(0))
# Out:
#     <script src="/static/components/requirejs/require.js"></script>
#     <script>
#       requirejs.config({
#         paths: {
#           base: '/static/base',
#           plotly: 'https://cdn.plot.ly/plotly-1.47.1.min.js?noext',
#         },
#       });
#     </script>
# INFO:tensorflow:Querying Tensorflow master (grpc://10.73.202.122:8470) for TPU system metadata.
# INFO:tensorflow:Found TPU system:
# INFO:tensorflow:*** Num TPU Cores: 8
# INFO:tensorflow:*** Num TPU Workers: 1
# INFO:tensorflow:*** Num TPU Cores Per Worker: 8
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:worker/replica:0/task:0/device:CPU:0, CPU, -1, 11018054164415147342)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:worker/replica:0/task:0/device:XLA_CPU:0, XLA_CPU, 17179869184, 14716372907037514274)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:worker/replica:0/task:0/device:TPU:0, TPU, 17179869184, 7087530949167762374)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:worker/replica:0/task:0/device:TPU:1, TPU, 17179869184, 6730544847693643781)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:worker/replica:0/task:0/device:TPU:2, TPU, 17179869184, 10607720766597758090)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:worker/replica:0/task:0/device:TPU:3, TPU, 17179869184, 6618352024309631303)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:worker/replica:0/task:0/device:TPU:4, TPU, 17179869184, 8297982378673060855)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:worker/replica:0/task:0/device:TPU:5, TPU, 17179869184, 17289277306947946089)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:worker/replica:0/task:0/device:TPU:6, TPU, 17179869184, 10077758960922048185)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:worker/replica:0/task:0/device:TPU:7, TPU, 17179869184, 9207348509280336552)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:worker/replica:0/task:0/device:TPU_SYSTEM:0, TPU_SYSTEM, 17179869184, 6314002470070112615)
# INFO:tensorflow:Calling model_fn.
# WARNING:tensorflow:From /content/fenwicks/data.py:376: DatasetV1.shard (from tensorflow.python.data.ops.dataset_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `dataset.apply(tf.data.experimental.filter_for_shard(...))`.
# ERROR:tensorflow:Operation of type Placeholder (input_1) is not supported on the TPU. Execution will fail if this op is used in the graph.
# /usr/local/lib/python3.6/dist-packages/keras_applications/resnet50.py:265: UserWarning:
#
# The output shape of `ResNet50(include_top=False)` has been changed since Keras 2.2.0.
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow/python/ops/losses/losses_impl.py:209: to_float (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.cast instead.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Warm-starting with WarmStartSettings: WarmStartSettings(ckpt_to_initialize_from='gs://gs_colab/model/ResNet50/keras', vars_to_warm_start=['res5c_branch2c/bias[^/]', 'res5c_branch2b/kernel[^/]', 'res5c_branch2b/bias[^/]', 'res5c_branch2a/kernel[^/]', 'res5a_branch2a/bias[^/]', 'res5a_branch1/bias[^/]', 'res4f_branch2c/bias[^/]', 'res4f_branch2b/kernel[^/]', 'res4f_branch2a/bias[^/]', 'res4e_branch2a/bias[^/]', 'res4d_branch2c/kernel[^/]', 'res4d_branch2c/bias[^/]', 'res4d_branch2b/kernel[^/]', 'res4d_branch2b/bias[^/]', 'res4d_branch2a/kernel[^/]', 'res4d_branch2a/bias[^/]', 'res4c_branch2c/kernel[^/]', 'res4c_branch2c/bias[^/]', 'res4c_branch2b/kernel[^/]', 'res4c_branch2b/bias[^/]', 'res4c_branch2a/bias[^/]', 'res4b_branch2b/bias[^/]', 'res4a_branch2c/kernel[^/]', 'res4a_branch2c/bias[^/]', 'res4a_branch2b/kernel[^/]', 'res4a_branch2b/bias[^/]', 'res4a_branch2a/bias[^/]', 'res4a_branch1/kernel[^/]', 'res3d_branch2c/kernel[^/]', 'res3d_branch2c/bias[^/]', 'res3d_branch2b/kernel[^/]', 'res3d_branch2b/bias[^/]', 'res3d_branch2a/kernel[^/]', 'res3c_branch2b/bias[^/]', 'res3b_branch2b/b
b/moving_mean[^/]', 'bn3c_branch2a/moving_variance[^/]', 'bn4d_branch2c/moving_variance[^/]', 'bn3b_branch2c/beta[^/]', 'bn5c_branch2a/moving_variance[^/]', 'bn4b_branch2c/moving_variance[^/]', 'bn3a_branch2c/moving_mean[^/]', 'bn2b_branch2a/moving_variance[^/]', 'bn4b_branch2b/beta[^/]', 'bn3b_branch2c/moving_mean[^/]', 'res4b_branch2b/kernel[^/]', 'bn3a_branch1/moving_mean[^/]', 'bn4d_branch2b/moving_mean[^/]', 'bn3c_branch2c/beta[^/]', 'res5c_branch2a/bias[^/]', 'res3a_branch2b/kernel[^/]', 'bn4e_branch2a/b ...
# INFO:tensorflow:Warm-starting from: ('gs://gs_colab/model/ResNet50/keras',)
# INFO:tensorflow:Warm-starting variable: res5c_branch2c/bias; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: res5c_branch2b/kernel; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: res5c_branch2b/bias; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: res5c_branch2a/kernel; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: res5a_branch2a/bias; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: res5a_branch1/bias; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: res4f_branch2c/bias; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: res4f_branch2b/kernel; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: res4f_branch2a/bias; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: res4e_branch2a/bias; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: res4d_branch2c/kernel; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: res4d_branch2c/bias; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: res4d_branch2b/kernel; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: res4d_branch2b/bias; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: res4d_branch2a/kernel; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: res4d_branch2a/bias; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: res4c_branch2c/kernel; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: res4c_branch2c/bias; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: res4c_branch2b/kernel; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: res4c_branch2b/bias; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: res4c_branch2a/bias; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: res4b_branch2b/bias; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: res4a_branch2c/kernel; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: res4a_branch2c/bias; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: res4a_branch2b/kernel; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: res4a_branch2b/bias; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: res4a_branch2a/bias; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: res4a_branch1/kernel; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: res3d_branch2c/kernel; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: res3d_branch2c/bias; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: res3d_branch2b/kernel; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: res3d_branch2b/bias; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: res3d_branch2a/kernel; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: res3c_branch2b/bias; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: res3b_branch2b/bias; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: res3b_branch2a/kernel; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: res3b_branch2a/bias; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: res3a_branch2c/kernel; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: res3a_branch2b/bias; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: res3a_branch2a/bias; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: res2c_branch2c/kernel; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: res2c_branch2c/bias; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: res3a_branch2a/kernel; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: res2c_branch2a/kernel; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: res2c_branch2a/bias; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: res2b_branch2c/bias; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: res2b_branch2a/bias; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: res2a_branch2c/kernel; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: res2a_branch2c/bias; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: res2b_branch2b/kernel; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: res2a_branch2b/bias; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: res2a_branch2a/bias; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: res2a_branch1/kernel; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: res2a_branch1/bias; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: res5b_branch2a/bias; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: global_step; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: res5b_branch2b/bias; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: bn_conv1/moving_variance; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: res3c_branch2b/kernel; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: bn_conv1/gamma; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: bn_conv1/beta; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: bn5c_branch2c/gamma; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: bn5c_branch2c/beta; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: bn5c_branch2b/moving_variance; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: bn5c_branch2b/gamma; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: res5b_branch2b/kernel; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: bn5c_branch2a/moving_mean; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: bn5c_branch2a/gamma; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: res4f_branch2a/kernel; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: bn5b_branch2c/moving_variance; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: res5a_branch2b/kernel; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: res3c_branch2a/bias; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: bn5b_branch2c/gamma; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: res4a_branch1/bias; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: bn5b_branch2b/moving_variance; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: bn5b_branch2b/gamma; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: res4a_branch2a/kernel; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: bn5b_branch2a/moving_mean; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: bn5b_branch2a/gamma; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: bn5b_branch2a/beta; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: bn5a_branch2c/moving_variance; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: bn5a_branch2c/moving_mean; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: res5c_branch2c/kernel; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: bn5a_branch2b/moving_mean; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: bn5a_branch2b/gamma; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: bn5a_branch2a/moving_mean; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: bn5a_branch2a/gamma; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: res3c_branch2a/kernel; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: bn5a_branch1/moving_variance; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: bn5b_branch2c/moving_mean; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: bn5a_branch1/gamma; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: bn5a_branch1/beta; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: bn4f_branch2c/moving_variance; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: bn4f_branch2c/moving_mean; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: bn3c_branch2a/gamma; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: bn5a_branch2c/beta; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: bn3d_branch2c/beta; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: bn4c_branch2c/gamma; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: res3c_branch2c/kernel; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: res3b_branch2c/bias; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: bn5b_branch2b/beta; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: bn3c_branch2b/gamma; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: bn4c_branch2c/beta; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: bn3c_branch2a/moving_mean; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: res4b_branch2c/bias; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: res2c_branch2b/kernel; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: bn3c_branch2b/moving_variance; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: bn5c_branch2c/moving_variance; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: bn4c_branch2c/moving_mean; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: res5a_branch2b/bias; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: bn3b_branch2c/gamma; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: bn3b_branch2a/beta; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: bn4c_branch2a/moving_variance; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: bn3c_branch2c/gamma; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: bn2a_branch2a/gamma; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: bn3a_branch2c/moving_variance; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: bn3a_branch2b/moving_mean; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: bn3c_branch2a/moving_variance; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: bn4d_branch2c/moving_variance; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: bn3b_branch2c/beta; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: bn5c_branch2a/moving_variance; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: bn4b_branch2c/moving_variance; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: bn3a_branch2c/moving_mean; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: bn2b_branch2a/moving_variance; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: bn4b_branch2b/beta; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: bn3b_branch2c/moving_mean; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: res4b_branch2b/kernel; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: bn3a_branch1/moving_mean; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: bn4d_branch2b/moving_mean; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: bn3c_branch2c/beta; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: res5c_branch2a/bias; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: res3a_branch2b/kernel; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: bn4e_branch2a/beta; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: res3b_branch2c/kernel; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: bn4e_branch2a/moving_variance; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: bn3a_branch1/gamma; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: bn2a_branch1/moving_variance; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: bn5c_branch2b/beta; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: bn3b_branch2b/gamma; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: bn4a_branch2b/moving_variance; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: bn2c_branch2c/beta; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: bn4a_branch1/moving_variance; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: bn3a_branch2b/gamma; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: bn2b_branch2b/moving_variance; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: res4b_branch2c/kernel; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: conv1/kernel; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: bn3b_branch2a/moving_mean; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: bn2c_branch2a/beta; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: bn4e_branch2a/moving_mean; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: bn5b_branch2b/moving_mean; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: bn2a_branch2a/moving_variance; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: res3c_branch2c/bias; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: bn2a_branch2b/gamma; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: bn4c_branch2b/gamma; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: bn3a_branch1/moving_variance; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: bn2a_branch2c/moving_variance; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: bn4c_branch2b/beta; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: bn2b_branch2a/gamma; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: res2b_branch2a/kernel; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: bn2a_branch2a/moving_mean; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: bn3d_branch2a/moving_variance; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: bn2b_branch2b/beta; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: bn4a_branch2a/moving_mean; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: bn2a_branch1/beta; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: bn2c_branch2c/gamma; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: bn3d_branch2c/moving_mean; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: bn3b_branch2b/moving_variance; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: bn3a_branch2c/beta; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: bn2a_branch2b/moving_variance; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: bn3a_branch2a/moving_mean; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: res4f_branch2b/bias; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: bn5a_branch1/moving_mean; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: bn3a_branch2a/beta; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: bn2b_branch2b/gamma; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: res5a_branch1/kernel; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: bn2c_branch2b/moving_mean; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: bn2c_branch2c/moving_mean; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: bn3c_branch2b/beta; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: bn2b_branch2c/beta; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: bn2a_branch1/gamma; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: bn2a_branch2c/moving_mean; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: bn4a_branch1/gamma; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: bn2c_branch2b/gamma; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: res4e_branch2c/kernel; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: bn4a_branch2b/gamma; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: res3a_branch1/bias; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: res2a_branch2a/kernel; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: bn4d_branch2a/beta; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: bn4b_branch2b/moving_mean; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: res2b_branch2c/kernel; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: bn3b_branch2b/moving_mean; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: bn2b_branch2c/gamma; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: bn4f_branch2b/beta; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: bn2b_branch2a/beta; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: bn2b_branch2b/moving_mean; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: bn3b_branch2b/beta; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: bn3a_branch2a/moving_variance; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: bn3b_branch2a/moving_variance; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: bn4c_branch2c/moving_variance; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: bn4a_branch2c/moving_variance; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: bn2a_branch2c/beta; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: bn3a_branch2c/gamma; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: bn2b_branch2c/moving_mean; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: res5a_branch2c/kernel; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: bn3a_branch2a/gamma; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: bn2a_branch2c/gamma; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: bn3c_branch2b/moving_mean; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: res4e_branch2a/kernel; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: bn4c_branch2a/beta; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: bn2b_branch2c/moving_variance; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: bn5a_branch2b/moving_variance; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: bn3d_branch2b/beta; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: bn4f_branch2a/gamma; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: bn2c_branch2a/moving_mean; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: res4c_branch2a/kernel; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: bn4b_branch2c/beta; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: bn4f_branch2a/moving_mean; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: bn3a_branch2b/beta; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: bn5a_branch2b/beta; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: bn5a_branch2a/moving_variance; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: bn3c_branch2c/moving_mean; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: conv1/bias; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: bn3a_branch2b/moving_variance; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: bn2c_branch2a/moving_variance; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: bn4e_branch2c/beta; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: res3b_branch2b/kernel; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: bn3d_branch2b/gamma; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: bn2c_branch2a/gamma; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: res5a_branch2a/kernel; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: bn2a_branch2b/moving_mean; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: bn2c_branch2b/beta; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: bn3a_branch1/beta; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: bn4a_branch2a/moving_variance; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: bn3c_branch2c/moving_variance; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: res2a_branch2b/kernel; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: bn5b_branch2a/moving_variance; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: bn3d_branch2a/moving_mean; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: bn3d_branch2b/moving_mean; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: bn4e_branch2b/moving_mean; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: res3d_branch2a/bias; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: res2c_branch2b/bias; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: bn4d_branch2c/gamma; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: res3a_branch2c/bias; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: bn3d_branch2b/moving_variance; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: bn3d_branch2c/moving_variance; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: bn3d_branch2c/gamma; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: bn4a_branch2a/gamma; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: bn4a_branch2b/beta; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: res4e_branch2c/bias; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: bn2a_branch1/moving_mean; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: bn4a_branch2b/moving_mean; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: bn4c_branch2b/moving_variance; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: bn5a_branch2a/beta; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: bn4a_branch2c/gamma; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: bn4a_branch2c/moving_mean; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: bn2a_branch2a/beta; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: bn4d_branch2a/moving_variance; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: res3a_branch1/kernel; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: bn4b_branch2a/gamma; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: bn3c_branch2a/beta; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: bn4b_branch2a/moving_mean; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: bn4a_branch1/moving_mean; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: bn4b_branch2a/moving_variance; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: bn5b_branch2c/beta; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: bn4b_branch2b/gamma; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: res5b_branch2c/bias; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: bn5c_branch2b/moving_mean; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: bn2a_branch2b/beta; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: bn4b_branch2b/moving_variance; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: bn4b_branch2c/gamma; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: res4b_branch2a/bias; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: bn4b_branch2c/moving_mean; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: bn2b_branch2a/moving_mean; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: bn2c_branch2b/moving_variance; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: bn4c_branch2a/gamma; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: bn5c_branch2c/moving_mean; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: bn4c_branch2a/moving_mean; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: bn4f_branch2b/gamma; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: res2b_branch2b/bias; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: bn4a_branch2c/beta; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: bn4c_branch2b/moving_mean; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: bn4d_branch2b/gamma; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: bn3b_branch2c/moving_variance; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: bn4d_branch2a/gamma; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: bn4a_branch1/beta; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: bn4d_branch2a/moving_mean; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: bn4d_branch2b/beta; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: bn4d_branch2c/moving_mean; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: bn4d_branch2b/moving_variance; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: bn5c_branch2a/beta; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: bn5a_branch2c/gamma; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: bn4d_branch2c/beta; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: bn4e_branch2b/beta; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: bn4e_branch2a/gamma; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: bn4a_branch2a/beta; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: bn4e_branch2b/gamma; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: res5b_branch2a/kernel; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: res5a_branch2c/bias; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: bn4e_branch2b/moving_variance; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: bn2c_branch2c/moving_variance; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: bn3d_branch2a/beta; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: bn4f_branch2b/moving_mean; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: res4b_branch2a/kernel; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: bn4e_branch2c/gamma; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: res5b_branch2c/kernel; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: res4f_branch2c/kernel; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: bn_conv1/moving_mean; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: bn4e_branch2c/moving_variance; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: bn4b_branch2a/beta; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: bn4f_branch2a/beta; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: bn4f_branch2c/gamma; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: bn3b_branch2a/gamma; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: bn3d_branch2a/gamma; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: bn4e_branch2c/moving_mean; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: bn4f_branch2a/moving_variance; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: res4e_branch2b/kernel; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: bn4f_branch2b/moving_variance; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: res4e_branch2b/bias; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: bn4f_branch2c/beta; prev_var_name: Unchanged
# INFO:tensorflow:TPU job name worker
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Saving checkpoints for 0 into gs://gs_colab/work/tutorial5/2019-05-16-15:44:07/model.ckpt.
# INFO:tensorflow:Initialized dataset iterators in 0 seconds
# INFO:tensorflow:Installing graceful shutdown hook.
# INFO:tensorflow:Creating heartbeat manager for ['/job:worker/replica:0/task:0/device:CPU:0']
# INFO:tensorflow:Configuring worker heartbeat: shutdown_mode: WAIT_FOR_COORDINATOR
#
# INFO:tensorflow:Init TPU system
# INFO:tensorflow:Initialized TPU in 7 seconds
# INFO:tensorflow:Starting infeed thread controller.
# INFO:tensorflow:Starting outfeed thread controller.
# INFO:tensorflow:Enqueue next (22) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (22) batch(es) of data from outfeed.
# INFO:tensorflow:loss = 1.5119317, step = 22
# INFO:tensorflow:Enqueue next (22) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (22) batch(es) of data from outfeed.
# INFO:tensorflow:Enqueue next (22) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (22) batch(es) of data from outfeed.
# INFO:tensorflow:Enqueue next (22) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (22) batch(es) of data from outfeed.
# INFO:tensorflow:Enqueue next (22) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (22) batch(es) of data from outfeed.
# INFO:tensorflow:Enqueue next (22) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (22) batch(es) of data from outfeed.
# INFO:tensorflow:loss = 0.12358735, step = 132 (14.769 sec)
# INFO:tensorflow:global_step/sec: 7.44827
# INFO:tensorflow:examples/sec: 953.379
# INFO:tensorflow:Enqueue next (22) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (22) batch(es) of data from outfeed.
# INFO:tensorflow:Enqueue next (22) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (22) batch(es) of data from outfeed.
# INFO:tensorflow:Enqueue next (22) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (22) batch(es) of data from outfeed.
# INFO:tensorflow:Enqueue next (22) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (22) batch(es) of data from outfeed.
# INFO:tensorflow:Enqueue next (22) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (22) batch(es) of data from outfeed.
# INFO:tensorflow:loss = 0.005812722, step = 242 (11.806 sec)
# INFO:tensorflow:global_step/sec: 9.31739
# INFO:tensorflow:examples/sec: 1192.63
# INFO:tensorflow:Saving checkpoints for 242 into gs://gs_colab/work/tutorial5/2019-05-16-15:44:07/model.ckpt.
# INFO:tensorflow:Stop infeed thread controller
# INFO:tensorflow:Shutting down InfeedController thread.
# INFO:tensorflow:InfeedController received shutdown signal, stopping.
# INFO:tensorflow:Infeed thread finished, shutting down.
# INFO:tensorflow:infeed marked as finished
# INFO:tensorflow:Stop output thread controller
# INFO:tensorflow:Shutting down OutfeedController thread.
# INFO:tensorflow:OutfeedController received shutdown signal, stopping.
# INFO:tensorflow:Outfeed thread finished, shutting down.
# INFO:tensorflow:outfeed marked as finished
# INFO:tensorflow:Shutdown TPU system.
# INFO:tensorflow:Loss for final step: 0.005812722.
# INFO:tensorflow:training_loop marked as finished
# INFO:tensorflow:Calling model_fn.
# ERROR:tensorflow:Operation of type Placeholder (input_1) is not supported on the TPU. Execution will fail if this op is used in the graph.
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow/contrib/tpu/python/tpu/tpu_estimator.py:2655: div (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Deprecated in favor of operator or tf.math.divide.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2019-05-16T15:45:35Z
# INFO:tensorflow:TPU job name worker
# INFO:tensorflow:Graph was finalized.
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow/python/training/saver.py:1266: checkpoint_exists (from tensorflow.python.training.checkpoint_management) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use standard file APIs to check for files with this prefix.
# INFO:tensorflow:Restoring parameters from gs://gs_colab/work/tutorial5/2019-05-16-15:44:07/model.ckpt-242
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Init TPU system
# INFO:tensorflow:Initialized TPU in 10 seconds
# INFO:tensorflow:Starting infeed thread controller.
# INFO:tensorflow:Starting outfeed thread controller.
# INFO:tensorflow:Initialized dataset iterators in 0 seconds
# INFO:tensorflow:Enqueue next (1) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1) batch(es) of data from outfeed.
# INFO:tensorflow:Evaluation [1/1]
# INFO:tensorflow:Stop infeed thread controller
# INFO:tensorflow:Shutting down InfeedController thread.
# INFO:tensorflow:InfeedController received shutdown signal, stopping.
# INFO:tensorflow:Infeed thread finished, shutting down.
# INFO:tensorflow:infeed marked as finished
# INFO:tensorflow:Stop output thread controller
# INFO:tensorflow:Shutting down OutfeedController thread.
# INFO:tensorflow:OutfeedController received shutdown signal, stopping.
# INFO:tensorflow:Outfeed thread finished, shutting down.
# INFO:tensorflow:outfeed marked as finished
# INFO:tensorflow:Shutdown TPU system.
# INFO:tensorflow:Finished evaluation at 2019-05-16-15:45:56
# INFO:tensorflow:Saving dict for global step 242: accuracy = 0.91346157, global_step = 242, loss = 1.5616204
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 242: gs://gs_colab/work/tutorial5/2019-05-16-15:44:07/model.ckpt-242
# INFO:tensorflow:evaluation_loop marked as finished

# %%
result.append(train_eval_fold(1))
# Out:
#     <script src="/static/components/requirejs/require.js"></script>
#     <script>
#       requirejs.config({
#         paths: {
#           base: '/static/base',
#           plotly: 'https://cdn.plot.ly/plotly-1.47.1.min.js?noext',
#         },
#       });
#     </script>
# INFO:tensorflow:Calling model_fn.
# ERROR:tensorflow:Operation of type Placeholder (input_1) is not supported on the TPU. Execution will fail if this op is used in the graph.
# /usr/local/lib/python3.6/dist-packages/keras_applications/resnet50.py:265: UserWarning:
#
# The output shape of `ResNet50(include_top=False)` has been changed since Keras 2.2.0.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Warm-starting with WarmStartSettings: WarmStartSettings(ckpt_to_initialize_from='gs://gs_colab/model/ResNet50/keras', vars_to_warm_start=['res5c_branch2c/bias[^/]', 'res5c_branch2b/kernel[^/]', 'res5c_branch2b/bias[^/]', 'res5c_branch2a/kernel[^/]', 'res5a_branch2a/bias[^/]', 'res5a_branch1/bias[^/]', 'res4f_branch2c/bias[^/]', 'res4f_branch2b/kernel[^/]', 'res4f_branch2a/bias[^/]', 'res4e_branch2a/bias[^/]', 'res4d_branch2c/kernel[^/]', 'res4d_branch2c/bias[^/]', 'res4d_branch2b/kernel[^/]', 'res4d_branch2b/bias[^/]', 'res4d_branch2a/kernel[^/]', 'res4d_branch2a/bias[^/]', 'res4c_branch2c/kernel[^/]', 'res4c_branch2c/bias[^/]', 'res4c_branch2b/kernel[^/]', 'res4c_branch2b/bias[^/]', 'res4c_branch2a/bias[^/]', 'res4b_branch2b/bias[^/]', 'res4a_branch2c/kernel[^/]', 'res4a_branch2c/bias[^/]', 'res4a_branch2b/kernel[^/]', 'res4a_branch2b/bias[^/]', 'res4a_branch2a/bias[^/]', 'res4a_branch1/kernel[^/]', 'res3d_branch2c/kernel[^/]', 'res3d_branch2c/bias[^/]', 'res3d_branch2b/kernel[^/]', 'res3d_branch2b/bias[^/]', 'res3d_branch2a/kernel[^/]', 'res3c_branch2b/bias[^/]', 'res3b_branch2b/bias[^/]', 'res3b_branch2a/kernel[^/]', 'res3b_branch2a/bias[^/]', 'res3a_branch2c/kernel[^/]', 'res3a_branch2b/bias[^/]', 'res3a_branch2a/bias[^/]', 'res2c_branch2c/kernel[^/]', 'res2c_branch2c/bias[^/]', 'res3a_branch2a/kernel[^/]', 'res2c_branch2a/kernel[^/]', 'res2c_branch2a/bias[^/]', 'res2b_branch2c/bias[^/]', 'res2b_branch2a/bias[^/]', 'res2a_branch2c/kernel[^/]', 'res2a_branch2c/bias[^/]', 'res2b_branch2b/kernel[^/]', 
...
# INFO:tensorflow:Warm-starting from: ('gs://gs_colab/model/ResNet50/keras',)
# INFO:tensorflow:Warm-starting variable: res5c_branch2c/bias; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: res5c_branch2b/kernel; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: res5c_branch2b/bias; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: res5c_branch2a/kernel; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: res5a_branch2a/bias; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: res5a_branch1/bias; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: res4f_branch2c/bias; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: res4f_branch2b/kernel; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: res4f_branch2a/bias; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: res4e_branch2a/bias; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: res4d_branch2c/kernel; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: res4d_branch2c/bias; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: res4d_branch2b/kernel; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: res4d_branch2b/bias; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: res4d_branch2a/kernel; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: res4d_branch2a/bias; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: res4c_branch2c/kernel; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: res4c_branch2c/bias; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: res4c_branch2b/kernel; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: res4c_branch2b/bias; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: res4c_branch2a/bias; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: res4b_branch2b/bias; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: res4a_branch2c/kernel; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: res4a_branch2c/bias; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: res4a_branch2b/kernel; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: res4a_branch2b/bias; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: res4a_branch2a/bias; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: res4a_branch1/kernel; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: res3d_branch2c/kernel; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: res3d_branch2c/bias; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: res3d_branch2b/kernel; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: res3d_branch2b/bias; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: res3d_branch2a/kernel; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: res3c_branch2b/bias; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: res3b_branch2b/bias; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: res3b_branch2a/kernel; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: res3b_branch2a/bias; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: res3a_branch2c/kernel; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: res3a_branch2b/bias; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: res3a_branch2a/bias; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: res2c_branch2c/kernel; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: res2c_branch2c/bias; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: res3a_branch2a/kernel; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: res2c_branch2a/kernel; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: res2c_branch2a/bias; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: res2b_branch2c/bias; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: res2b_branch2a/bias; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: res2a_branch2c/kernel; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: res2a_branch2c/bias; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: res2b_branch2b/kernel; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: res2a_branch2b/bias; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: res2a_branch2a/bias; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: res2a_branch1/kernel; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: res2a_branch1/bias; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: res5b_branch2a/bias; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: global_step; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: res5b_branch2b/bias; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: bn_conv1/moving_variance; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: res3c_branch2b/kernel; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: bn_conv1/gamma; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: bn_conv1/beta; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: bn5c_branch2c/gamma; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: bn5c_branch2c/beta; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: bn5c_branch2b/moving_variance; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: bn5c_branch2b/gamma; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: res5b_branch2b/kernel; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: bn5c_branch2a/moving_mean; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: bn5c_branch2a/gamma; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: res4f_branch2a/kernel; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: bn5b_branch2c/moving_variance; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: res5a_branch2b/kernel; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: res3c_branch2a/bias; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: bn5b_branch2c/gamma; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: res4a_branch1/bias; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: bn5b_branch2b/moving_variance; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: bn5b_branch2b/gamma; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: res4a_branch2a/kernel; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: bn5b_branch2a/moving_mean; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: bn5b_branch2a/gamma; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: bn5b_branch2a/beta; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: bn5a_branch2c/moving_variance; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: bn5a_branch2c/moving_mean; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: res5c_branch2c/kernel; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: bn5a_branch2b/moving_mean; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: bn5a_branch2b/gamma; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: bn5a_branch2a/moving_mean; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: bn5a_branch2a/gamma; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: res3c_branch2a/kernel; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: bn5a_branch1/moving_variance; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: bn5b_branch2c/moving_mean; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: bn5a_branch1/gamma; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: bn5a_branch1/beta; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: bn4f_branch2c/moving_variance; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: bn4f_branch2c/moving_mean; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: bn3c_branch2a/gamma; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: bn5a_branch2c/beta; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: bn3d_branch2c/beta; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: bn4c_branch2c/gamma; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: res3c_branch2c/kernel; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: res3b_branch2c/bias; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: bn5b_branch2b/beta; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: bn3c_branch2b/gamma; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: bn4c_branch2c/beta; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: bn3c_branch2a/moving_mean; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: res4b_branch2c/bias; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: res2c_branch2b/kernel; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: bn3c_branch2b/moving_variance; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: bn5c_branch2c/moving_variance; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: bn4c_branch2c/moving_mean; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: res5a_branch2b/bias; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: bn3b_branch2c/gamma; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: bn3b_branch2a/beta; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: bn4c_branch2a/moving_variance; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: bn3c_branch2c/gamma; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: bn2a_branch2a/gamma; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: bn3a_branch2c/moving_variance; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: bn3a_branch2b/moving_mean; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: bn3c_branch2a/moving_variance; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: bn4d_branch2c/moving_variance; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: bn3b_branch2c/beta; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: bn5c_branch2a/moving_variance; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: bn4b_branch2c/moving_variance; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: bn3a_branch2c/moving_mean; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: bn2b_branch2a/moving_variance; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: bn4b_branch2b/beta; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: bn3b_branch2c/moving_mean; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: res4b_branch2b/kernel; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: bn3a_branch1/moving_mean; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: bn4d_branch2b/moving_mean; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: bn3c_branch2c/beta; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: res5c_branch2a/bias; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: res3a_branch2b/kernel; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: bn4e_branch2a/beta; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: res3b_branch2c/kernel; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: bn4e_branch2a/moving_variance; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: bn3a_branch1/gamma; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: bn2a_branch1/moving_variance; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: bn5c_branch2b/beta; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: bn3b_branch2b/gamma; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: bn4a_branch2b/moving_variance; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: bn2c_branch2c/beta; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: bn4a_branch1/moving_variance; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: bn3a_branch2b/gamma; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: bn2b_branch2b/moving_variance; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: res4b_branch2c/kernel; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: conv1/kernel; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: bn3b_branch2a/moving_mean; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: bn2c_branch2a/beta; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: bn4e_branch2a/moving_mean; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: bn5b_branch2b/moving_mean; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: bn2a_branch2a/moving_variance; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: res3c_branch2c/bias; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: bn2a_branch2b/gamma; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: bn4c_branch2b/gamma; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: bn3a_branch1/moving_variance; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: bn2a_branch2c/moving_variance; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: bn4c_branch2b/beta; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: bn2b_branch2a/gamma; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: res2b_branch2a/kernel; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: bn2a_branch2a/moving_mean; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: bn3d_branch2a/moving_variance; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: bn2b_branch2b/beta; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: bn4a_branch2a/moving_mean; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: bn2a_branch1/beta; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: bn2c_branch2c/gamma; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: bn3d_branch2c/moving_mean; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: bn3b_branch2b/moving_variance; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: bn3a_branch2c/beta; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: bn2a_branch2b/moving_variance; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: bn3a_branch2a/moving_mean; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: res4f_branch2b/bias; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: bn5a_branch1/moving_mean; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: bn3a_branch2a/beta; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: bn2b_branch2b/gamma; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: res5a_branch1/kernel; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: bn2c_branch2b/moving_mean; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: bn2c_branch2c/moving_mean; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: bn3c_branch2b/beta; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: bn2b_branch2c/beta; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: bn2a_branch1/gamma; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: bn2a_branch2c/moving_mean; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: bn4a_branch1/gamma; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: bn2c_branch2b/gamma; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: res4e_branch2c/kernel; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: bn4a_branch2b/gamma; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: res3a_branch1/bias; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: res2a_branch2a/kernel; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: bn4d_branch2a/beta; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: bn4b_branch2b/moving_mean; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: res2b_branch2c/kernel; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: bn3b_branch2b/moving_mean; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: bn2b_branch2c/gamma; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: bn4f_branch2b/beta; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: bn2b_branch2a/beta; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: bn2b_branch2b/moving_mean; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: bn3b_branch2b/beta; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: bn3a_branch2a/moving_variance; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: bn3b_branch2a/moving_variance; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: bn4c_branch2c/moving_variance; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: bn4a_branch2c/moving_variance; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: bn2a_branch2c/beta; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: bn3a_branch2c/gamma; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: bn2b_branch2c/moving_mean; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: res5a_branch2c/kernel; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: bn3a_branch2a/gamma; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: bn2a_branch2c/gamma; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: bn3c_branch2b/moving_mean; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: res4e_branch2a/kernel; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: bn4c_branch2a/beta; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: bn2b_branch2c/moving_variance; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: bn5a_branch2b/moving_variance; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: bn3d_branch2b/beta; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: bn4f_branch2a/gamma; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: bn2c_branch2a/moving_mean; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: res4c_branch2a/kernel; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: bn4b_branch2c/beta; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: bn4f_branch2a/moving_mean; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: bn3a_branch2b/beta; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: bn5a_branch2b/beta; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: bn5a_branch2a/moving_variance; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: bn3c_branch2c/moving_mean; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: conv1/bias; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: bn3a_branch2b/moving_variance; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: bn2c_branch2a/moving_variance; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: bn4e_branch2c/beta; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: res3b_branch2b/kernel; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: bn3d_branch2b/gamma; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: bn2c_branch2a/gamma; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: res5a_branch2a/kernel; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: bn2a_branch2b/moving_mean; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: bn2c_branch2b/beta; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: bn3a_branch1/beta; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: bn4a_branch2a/moving_variance; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: bn3c_branch2c/moving_variance; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: res2a_branch2b/kernel; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: bn5b_branch2a/moving_variance; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: bn3d_branch2a/moving_mean; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: bn3d_branch2b/moving_mean; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: bn4e_branch2b/moving_mean; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: res3d_branch2a/bias; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: res2c_branch2b/bias; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: bn4d_branch2c/gamma; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: res3a_branch2c/bias; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: bn3d_branch2b/moving_variance; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: bn3d_branch2c/moving_variance; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: bn3d_branch2c/gamma; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: bn4a_branch2a/gamma; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: bn4a_branch2b/beta; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: res4e_branch2c/bias; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: bn2a_branch1/moving_mean; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: bn4a_branch2b/moving_mean; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: bn4c_branch2b/moving_variance; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: bn5a_branch2a/beta; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: bn4a_branch2c/gamma; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: bn4a_branch2c/moving_mean; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: bn2a_branch2a/beta; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: bn4d_branch2a/moving_variance; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: res3a_branch1/kernel; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: bn4b_branch2a/gamma; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: bn3c_branch2a/beta; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: bn4b_branch2a/moving_mean; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: bn4a_branch1/moving_mean; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: bn4b_branch2a/moving_variance; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: bn5b_branch2c/beta; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: bn4b_branch2b/gamma; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: res5b_branch2c/bias; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: bn5c_branch2b/moving_mean; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: bn2a_branch2b/beta; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: bn4b_branch2b/moving_variance; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: bn4b_branch2c/gamma; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: res4b_branch2a/bias; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: bn4b_branch2c/moving_mean; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: bn2b_branch2a/moving_mean; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: bn2c_branch2b/moving_variance; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: bn4c_branch2a/gamma; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: bn5c_branch2c/moving_mean; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: bn4c_branch2a/moving_mean; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: bn4f_branch2b/gamma; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: res2b_branch2b/bias; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: bn4a_branch2c/beta; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: bn4c_branch2b/moving_mean; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: bn4d_branch2b/gamma; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: bn3b_branch2c/moving_variance; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: bn4d_branch2a/gamma; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: bn4a_branch1/beta; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: bn4d_branch2a/moving_mean; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: bn4d_branch2b/beta; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: bn4d_branch2c/moving_mean; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: bn4d_branch2b/moving_variance; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: bn5c_branch2a/beta; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: bn5a_branch2c/gamma; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: bn4d_branch2c/beta; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: bn4e_branch2b/beta; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: bn4e_branch2a/gamma; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: bn4a_branch2a/beta; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: bn4e_branch2b/gamma; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: res5b_branch2a/kernel; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: res5a_branch2c/bias; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: bn4e_branch2b/moving_variance; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: bn2c_branch2c/moving_variance; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: bn3d_branch2a/beta; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: bn4f_branch2b/moving_mean; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: res4b_branch2a/kernel; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: bn4e_branch2c/gamma; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: res5b_branch2c/kernel; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: res4f_branch2c/kernel; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: bn_conv1/moving_mean; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: bn4e_branch2c/moving_variance; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: bn4b_branch2a/beta; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: bn4f_branch2a/beta; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: bn4f_branch2c/gamma; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: bn3b_branch2a/gamma; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: bn3d_branch2a/gamma; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: bn4e_branch2c/moving_mean; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: bn4f_branch2a/moving_variance; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: res4e_branch2b/kernel; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: bn4f_branch2b/moving_variance; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: res4e_branch2b/bias; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: bn4f_branch2c/beta; prev_var_name: Unchanged
# INFO:tensorflow:TPU job name worker
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Saving checkpoints for 0 into gs://gs_colab/work/tutorial5/2019-05-16-15:44:07/model.ckpt.
# INFO:tensorflow:Initialized dataset iterators in 0 seconds
# INFO:tensorflow:Installing graceful shutdown hook.
# INFO:tensorflow:Creating heartbeat manager for ['/job:worker/replica:0/task:0/device:CPU:0']
# INFO:tensorflow:Configuring worker heartbeat: shutdown_mode: WAIT_FOR_COORDINATOR
#
# INFO:tensorflow:Init TPU system
# INFO:tensorflow:Initialized TPU in 13 seconds
# INFO:tensorflow:Starting infeed thread controller.
# INFO:tensorflow:Starting outfeed thread controller.
# INFO:tensorflow:Enqueue next (22) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (22) batch(es) of data from outfeed.
# INFO:tensorflow:loss = 2.0727408, step = 22
# INFO:tensorflow:Enqueue next (22) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (22) batch(es) of data from outfeed.
# INFO:tensorflow:Enqueue next (22) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (22) batch(es) of data from outfeed.
# INFO:tensorflow:Enqueue next (22) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (22) batch(es) of data from outfeed.
# INFO:tensorflow:Enqueue next (22) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (22) batch(es) of data from outfeed.
# INFO:tensorflow:Enqueue next (22) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (22) batch(es) of data from outfeed.
# INFO:tensorflow:loss = 0.4933868, step = 132 (15.573 sec)
# INFO:tensorflow:global_step/sec: 7.06356
# INFO:tensorflow:examples/sec: 904.135
# INFO:tensorflow:Enqueue next (22) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (22) batch(es) of data from outfeed.
# INFO:tensorflow:Enqueue next (22) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (22) batch(es) of data from outfeed.
# INFO:tensorflow:Enqueue next (22) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (22) batch(es) of data from outfeed.
# INFO:tensorflow:Enqueue next (22) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (22) batch(es) of data from outfeed.
# INFO:tensorflow:Enqueue next (22) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (22) batch(es) of data from outfeed.
# INFO:tensorflow:loss = 7.9200334e-05, step = 242 (12.791 sec)
# INFO:tensorflow:global_step/sec: 8.59868
# INFO:tensorflow:examples/sec: 1100.63
# INFO:tensorflow:Saving checkpoints for 242 into gs://gs_colab/work/tutorial5/2019-05-16-15:44:07/model.ckpt.
# INFO:tensorflow:Stop infeed thread controller
# INFO:tensorflow:Shutting down InfeedController thread.
# INFO:tensorflow:InfeedController received shutdown signal, stopping.
# INFO:tensorflow:Infeed thread finished, shutting down.
# INFO:tensorflow:infeed marked as finished
# INFO:tensorflow:Stop output thread controller
# INFO:tensorflow:Shutting down OutfeedController thread.
# INFO:tensorflow:OutfeedController received shutdown signal, stopping.
# INFO:tensorflow:Outfeed thread finished, shutting down.
# INFO:tensorflow:outfeed marked as finished
# INFO:tensorflow:Shutdown TPU system.
# INFO:tensorflow:Loss for final step: 7.9200334e-05.
# INFO:tensorflow:training_loop marked as finished
# INFO:tensorflow:Calling model_fn.
# ERROR:tensorflow:Operation of type Placeholder (input_1) is not supported on the TPU. Execution will fail if this op is used in the graph.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2019-05-16T15:47:36Z
# INFO:tensorflow:TPU job name worker
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from gs://gs_colab/work/tutorial5/2019-05-16-15:44:07/model.ckpt-242
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Init TPU system
# INFO:tensorflow:Initialized TPU in 11 seconds
# INFO:tensorflow:Starting infeed thread controller.
# INFO:tensorflow:Starting outfeed thread controller.
# INFO:tensorflow:Initialized dataset iterators in 0 seconds
# INFO:tensorflow:Enqueue next (1) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1) batch(es) of data from outfeed.
# INFO:tensorflow:Evaluation [1/1]
# INFO:tensorflow:Stop infeed thread controller
# INFO:tensorflow:Shutting down InfeedController thread.
# INFO:tensorflow:InfeedController received shutdown signal, stopping.
# INFO:tensorflow:Infeed thread finished, shutting down.
# INFO:tensorflow:infeed marked as finished
# INFO:tensorflow:Stop output thread controller
# INFO:tensorflow:Shutting down OutfeedController thread.
# INFO:tensorflow:OutfeedController received shutdown signal, stopping.
# INFO:tensorflow:Outfeed thread finished, shutting down.
# INFO:tensorflow:outfeed marked as finished
# INFO:tensorflow:Shutdown TPU system.
# INFO:tensorflow:Finished evaluation at 2019-05-16-15:47:59
# INFO:tensorflow:Saving dict for global step 242: accuracy = 0.90247256, global_step = 242, loss = 1.4889208
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 242: gs://gs_colab/work/tutorial5/2019-05-16-15:44:07/model.ckpt-242
# INFO:tensorflow:evaluation_loop marked as finished

# %%
result.append(train_eval_fold(2))
# Out:
#     <script src="/static/components/requirejs/require.js"></script>
#     <script>
#       requirejs.config({
#         paths: {
#           base: '/static/base',
#           plotly: 'https://cdn.plot.ly/plotly-1.47.1.min.js?noext',
#         },
#       });
#     </script>
# INFO:tensorflow:Calling model_fn.
# ERROR:tensorflow:Operation of type Placeholder (input_1) is not supported on the TPU. Execution will fail if this op is used in the graph.
# /usr/local/lib/python3.6/dist-packages/keras_applications/resnet50.py:265: UserWarning:
#
# The output shape of `ResNet50(include_top=False)` has been changed since Keras 2.2.0.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Warm-starting with WarmStartSettings: WarmStartSettings(ckpt_to_initialize_from='gs://gs_colab/model/ResNet50/keras', vars_to_warm_start=['res5c_branch2c/bias[^/]', 'res5c_branch2b/kernel[^/]', 'res5c_branch2b/bias[^/]', 'res5c_branch2a/kernel[^/]', 'res5a_branch2a/bias[^/]', 'res5a_branch1/bias[^/]', 'res4f_branch2c/bias[^/]', 'res4f_branch2b/kernel[^/]', 'res4f_branch2a/bias[^/]', 'res4e_branch2a/bias[^/]', 'res4d_branch2c/kernel[^/]', 'res4d_branch2c/bias[^/]', 'res4d_branch2b/kernel[^/]', 'res4d_branch2b/bias[^/]', 'res4d_branch2a/kernel[^/]', 'res4d_branch2a/bias[^/]', 'res4c_branch2c/kernel[^/]', 'res4c_branch2c/bias[^/]', 'res4c_branch2b/kernel[^/]', 'res4c_branch2b/bias[^/]', 'res4c_branch2a/bias[^/]', 'res4b_branch2b/bias[^/]', 'res4a_branch2c/kernel[^/]', 'res4a_branch2c/bias[^/]', 'res4a_branch2b/kernel[^/]', 'res4a_branch2b/bias[^/]', 'res4a_branch2a/bias[^/]', 'res4a_branch1/kernel[^/]', 'res3d_branch2c/kernel[^/]', 'res3d_branch2c/bias[^/]', 'res3d_branch2b/kernel[^/]', 'res3d_branch2b/bias[^/]', 'res3d_branch2a/kernel[^/]', 'res3c_branch2b/bias[^/]', 'res3b_branch2b/bias[^/]', 'res3b_branch2a/kernel[^/]', 'res3b_branch2a/bias[^/]', 'res3a_branch2c/kernel[^/]', 'res3a_branch2b/bias[^/]', 'res3a_branch2a/bias[^/]', 'res2c_branch2c/kernel[^/]', 'res2c_branch2c/bias[^/]', 'res3a_branch2a/kernel[^/]', 'res2c_branch2a/kernel[^/]', 'res2c_branch2a/bias[^/]', 'res2b_branch2c/bias[^/]', 'res2b_branch2a/bias[^/]', 'res2a_branch2c/kernel[^/]', 'res2a_branch2c/bias[^/]', 'res2b_branch2b/kernel[^/]', 'res2a_branch2b/bias[^/]', 'res2a_branch2a/bias[^/]', 'res2a_branch1/kernel[^/]', 'res2a_branch1/bias[^/]', 'res5b_branch2a/bias[^/]', 'global_step[^/]', 'res5b_branch2b/bias[^/]', 'bn_conv1/moving_variance[^/]', 'res3c_branch2b/kernel[^/]', 'bn_conv1/gamma[^/]', 'bn_conv1/beta[^/]', 'bn5c_branch2c/gamma[^/]', 'bn5c_branch2c/beta[^/]', 'bn5c_branch2b/moving_variance[^/]', 'bn5c_branch2b/gamma[^/]', 'res5
seconds
# INFO:tensorflow:Starting infeed thread controller.
# INFO:tensorflow:Starting outfeed thread controller.
# INFO:tensorflow:Initialized dataset iterators in 0 seconds
# INFO:tensorflow:Enqueue next (1) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1) batch(es) of data from outfeed.
# INFO:tensorflow:Evaluation [1/1]
# INFO:tensorflow:Stop infeed thread controller
# INFO:tensorflow:Shutting down InfeedController thread.
# INFO:tensorflow:InfeedController received shutdown signal, stopping.
# INFO:tensorflow:Infeed thread finished, shutting down.
# INFO:tensorflow:infeed marked as finished
# INFO:tensorflow:Stop output thread controller
# INFO:tensorflow:Shutting down OutfeedController thread.
# INFO:tensorflow:OutfeedController received shutdown signal, stopping.
# INFO:tensorflow:Outfeed thread finished, shutting down.
# INFO:tensorflow:outfeed marked as finished
# INFO:tensorflow:Shutdown TPU system.
# INFO:tensorflow:Finished evaluation at 2019-05-16-15:49:59
# INFO:tensorflow:Saving dict for global step 242: accuracy = 0.9093407, global_step = 242, loss = 1.3781284
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 242: gs://gs_colab/work/tutorial5/2019-05-16-15:44:07/model.ckpt-242
# INFO:tensorflow:evaluation_loop marked as finished

# %%
result.append(train_eval_fold(3))
# Out:
#     <script src="/static/components/requirejs/require.js"></script>
#     <script>
#       requirejs.config({
#         paths: {
#           base: '/static/base',
#           plotly: 'https://cdn.plot.ly/plotly-1.47.1.min.js?noext',
#         },
#       });
#     </script>
# INFO:tensorflow:Calling model_fn.
# ERROR:tensorflow:Operation of type Placeholder (input_1) is not supported on the TPU. Execution will fail if this op is used in the graph.
# /usr/local/lib/python3.6/dist-packages/keras_applications/resnet50.py:265: UserWarning:
#
# The output shape of `ResNet50(include_top=False)` has been changed since Keras 2.2.0.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Warm-starting with WarmStartSettings: WarmStartSettings(ckpt_to_initialize_from='gs://gs_colab/model/ResNet50/keras', vars_to_warm_start=['res5c_branch2c/bias[^/]', 'res5c_branch2b/kernel[^/]', 'res5c_branch2b/bias[^/]', 'res5c_branch2a/kernel[^/]', 'res5a_branch2a/bias[^/]', 'res5a_branch1/bias[^/]', 'res4f_branch2c/bias[^/]', 'res4f_branch2b/kernel[^/]', 'res4f_branch2a/bias[^/]', 'res4e_branch2a/bias[^/]', 'res4d_branch2c/kernel[^/]', 'res4d_branch2c/bias[^/]', 'res4d_branch2b/kernel[^/]', 'res4d_branch2b/bias[^/]', 'res4d_branch2a/kernel[^/]', 'res4d_branch2a/bias[^/]', 'res4c_branch2c/kernel[^/]', 'res4c_branch2c/bias[^/]', 'res4c_branch2b/kernel[^/]', 'res4c_branch2b/bias[^/]', 'res4c_branch2a/bias[^/]', 'res4b_branch2b/bias[^/]', 'res4a_branch2c/kernel[^/]', 'res4a_branch2c/bias[^/]', 'res4a_branch2b/kernel[^/]', 'res4a_branch2b/bias[^/]', 'res4a_branch2a/bias[^/]', 'res4a_branch1/kernel[^/]', 'res3d_branch2c/kernel[^/]', 'res3d_branch2c/bias[^/]', 'res3d_branch2b/kernel[^/]', 'res3d_branch2b/bias[^/]', 'res3d_branch2a/kernel[^/]', 'res3c_branch2b/bias[^/]', 'res3b_branch2b/bias[^/]', 'res3b_branch2a/kernel[^/]', 'res3b_branch2a/bias[^/]', 'res3a_branch2c/kernel[^/]', 'res3a_branch2b/bias[^/]', 'res3a_branch2a/bias[^/]', 'res2c_branch2c/kernel[^/]', 'res2c_branch2c/bias[^/]', 'res3a_branch2a/kernel[^/]', 'res2c_branch2a/kernel[^/]', 'res2c_branch2a/bias[^/]', 'res2b_branch2c/bias[^/]', 'res2b_branch2a/bias[^/]', 'res2a_branch2c/kernel[^/]', 'res2a_branch2c/bias[^/]', 'res2b_branch2b/kernel[^/]', 'res2a_branch2b/bias[^/]', 'res2a_branch2a/bias[^/]', 'res2a_branch1/kernel[^/]', 'res2a_branch1/bias[^/]', 'res5b_branch2a/bias[^/]', 'global_step[^/]', 'res5b_branch2b/bias[^/]', 'bn_conv1/moving_variance[^/]', 'res3c_branch2b/kernel[^/]', 'bn_conv1/gamma[^/]', 'bn_conv1/beta[^/]', 'bn5c_branch2c/gamma[^/]', 'bn5c_branch2c/beta[^/]', 'bn5c_branch2b/moving_variance[^/]', 'bn5c_branch2b/gamma[^/]', 'res5b_branch2b/kernel[^/]', 'bn5c_branch2a/moving_mean[^/]', 'bn5c_branch2a/gamma[^/]', 'res4f_branch2a/kernel[^/]', 'bn5b_branch2c/moving_variance[^/]', 'res5a_branch2b/kernel[^/]', 'res3c_branch2a/bias[^/]', 'bn5b_branch2c/gamma[^/]', 'res4a_branch1/bias[^/]', 'bn5b_branch2b/moving_variance[^/]', 'bn5b_branch2b/gamma[^/]', 'res4a_branch2a/kernel[^/]', 'bn5b_branch2a/moving_mean[^/]', 'bn5b_branch2a/gamma[^/]', 'bn5b_branch2a/beta[^/]', 'bn5a_branch2c/moving_variance[^/]', 'bn5a_branch2c/moving_mean[^/]', 'res5c_branch2c/kernel[^/]', 'bn5a_branch2b/moving_mean[^/]', 'bn5a_branch2b/gamma[^/]', 'bn5a_branch2a/moving_mean[^/]', 'bn5a_branch2a/gamma[^/]', 'res3c_branch2a/kernel[^/]', 'bn5a_branch1/moving_variance[^/]', 'bn5b_branch2c/moving_mean[^/]', 'bn5a_branch1/gamma[^/]', 'bn5a_branch1/beta[^/]', 'bn4f_branch2c/moving_variance[^/]', 'bn4f_branch2c/moving_mean[^/]', 'bn3c_branch2a/gamma[^/]', 'bn5a_branch2c/beta[^/]', 'bn3d_branch2c/beta[^/]', 'bn4c_branch2c/gamma[^/]', 'res3c_branch2c/kernel[^/]', 'res3b_branch2c/bias[^/]', 'bn5b_branch2b/beta[^/]', 'bn3c_branch2b/gamma[^/]', 'bn4c_branch2c/beta[^/]', 'bn3c_branch2a/moving_mean[^/]', 'res4b_branch2c/bias[^/]', 'res2c_branch2b/kernel[^/]', 'bn3c_branch2b/moving_variance[^/]', 'bn5c_branch2c/moving_variance[^/]', 'bn4c_branch2c/moving_mean[^/]', 'res5a_branch2b/bias[^/]', 'bn3b_branch2c/gamma[^/]', 'bn3b_branch2a/beta[^/]', 'bn4c_branch2a/moving_variance[^/]', 'bn3c_branch2c/gamma[^/]', 'bn2a_branch2a/gamma[^/]', 'bn3a_branch2c/moving_variance[^/]', 'bn3a_branch2b/moving_mean[^/]', 'bn3c_branch2a/moving_variance[^/]', 'bn4d_branch2c/moving_variance[^/]', 'bn3b_branch2c/beta[^/]', 'bn5c_branch2a/moving_variance[^/]', 'bn4b_branch2c/moving_variance[^/]', 'bn3a_branch2c/moving_mean[^/]', 'bn2b_branch2a/moving_variance[^/]', 'bn4b_branch2b/beta[^/]', 'bn3b_branch2c/moving_mean[^/]', 'res4b_branch2b/kernel[^/]', 'bn3a_branch1/moving_mean[^/]', 'bn4d_branch2b/moving_mean[^/]', 'bn3c_branch2c/beta[^/]', 'res5c_branch2a/bias[^/]', 'res3a_branch2b/kernel[^/]', 'bn4e_branch2a/b ...
# INFO:tensorflow:Warm-starting from: ('gs://gs_colab/model/ResNet50/keras',)
# INFO:tensorflow:Warm-starting variable: res5c_branch2c/bias; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: res5c_branch2b/kernel; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: res5c_branch2b/bias; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: res5c_branch2a/kernel; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: res5a_branch2a/bias; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: res5a_branch1/bias; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: res4f_branch2c/bias; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: res4f_branch2b/kernel; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: res4f_branch2a/bias; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: res4e_branch2a/bias; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: res4d_branch2c/kernel; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: res4d_branch2c/bias; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: res4d_branch2b/kernel; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: res4d_branch2b/bias; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: res4d_branch2a/kernel; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: res4d_branch2a/bias; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: res4c_branch2c/kernel; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: res4c_branch2c/bias; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: res4c_branch2b/kernel; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: res4c_branch2b/bias; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: res4c_branch2a/bias; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: res4b_branch2b/bias; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: res4a_branch2c/kernel; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: res4a_branch2c/bias; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: res4a_branch2b/kernel; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: res4a_branch2b/bias; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: res4a_branch2a/bias; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: res4a_branch1/kernel; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: res3d_branch2c/kernel; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: res3d_branch2c/bias; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: res3d_branch2b/kernel; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: res3d_branch2b/bias; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: res3d_branch2a/kernel; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: res3c_branch2b/bias; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: res3b_branch2b/bias; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: res3b_branch2a/kernel; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: res3b_branch2a/bias; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: res3a_branch2c/kernel; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: res3a_branch2b/bias; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: res3a_branch2a/bias; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: res2c_branch2c/kernel; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: res2c_branch2c/bias; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: res3a_branch2a/kernel; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: res2c_branch2a/kernel; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: res2c_branch2a/bias; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: res2b_branch2c/bias; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: res2b_branch2a/bias; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: res2a_branch2c/kernel; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: res2a_branch2c/bias; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: res2b_branch2b/kernel; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: res2a_branch2b/bias; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: res2a_branch2a/bias; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: res2a_branch1/kernel; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: res2a_branch1/bias; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: res5b_branch2a/bias; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: global_step; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: res5b_branch2b/bias; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: bn_conv1/moving_variance; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: res3c_branch2b/kernel; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: bn_conv1/gamma; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: bn_conv1/beta; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: bn5c_branch2c/gamma; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: bn5c_branch2c/beta; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: bn5c_branch2b/moving_variance; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: bn5c_branch2b/gamma; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: res5b_branch2b/kernel; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: bn5c_branch2a/moving_mean; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: bn5c_branch2a/gamma; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: res4f_branch2a/kernel; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: bn5b_branch2c/moving_variance; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: res5a_branch2b/kernel; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: res3c_branch2a/bias; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: bn5b_branch2c/gamma; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: res4a_branch1/bias; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: bn5b_branch2b/moving_variance; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: bn5b_branch2b/gamma; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: res4a_branch2a/kernel; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: bn5b_branch2a/moving_mean; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: bn5b_branch2a/gamma; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: bn5b_branch2a/beta; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: bn5a_branch2c/moving_variance; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: bn5a_branch2c/moving_mean; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: res5c_branch2c/kernel; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: bn5a_branch2b/moving_mean; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: bn5a_branch2b/gamma; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: bn5a_branch2a/moving_mean; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: bn5a_branch2a/gamma; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: res3c_branch2a/kernel; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: bn5a_branch1/moving_variance; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: bn5b_branch2c/moving_mean; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: bn5a_branch1/gamma; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: bn5a_branch1/beta; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: bn4f_branch2c/moving_variance; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: bn4f_branch2c/moving_mean; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: bn3c_branch2a/gamma; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: bn5a_branch2c/beta; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: bn3d_branch2c/beta; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: bn4c_branch2c/gamma; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: res3c_branch2c/kernel; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: res3b_branch2c/bias; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: bn5b_branch2b/beta; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: bn3c_branch2b/gamma; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: bn4c_branch2c/beta; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: bn3c_branch2a/moving_mean; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: res4b_branch2c/bias; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: res2c_branch2b/kernel; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: bn3c_branch2b/moving_variance; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: bn5c_branch2c/moving_variance; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: bn4c_branch2c/moving_mean; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: res5a_branch2b/bias; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: bn3b_branch2c/gamma; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: bn3b_branch2a/beta; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: bn4c_branch2a/moving_variance; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: bn3c_branch2c/gamma; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: bn2a_branch2a/gamma; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: bn3a_branch2c/moving_variance; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: bn3a_branch2b/moving_mean; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: bn3c_branch2a/moving_variance; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: bn4d_branch2c/moving_variance; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: bn3b_branch2c/beta; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: bn5c_branch2a/moving_variance; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: bn4b_branch2c/moving_variance; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: bn3a_branch2c/moving_mean; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: bn2b_branch2a/moving_variance; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: bn4b_branch2b/beta; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: bn3b_branch2c/moving_mean; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: res4b_branch2b/kernel; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: bn3a_branch1/moving_mean; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: bn4d_branch2b/moving_mean; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: bn3c_branch2c/beta; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: res5c_branch2a/bias; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: res3a_branch2b/kernel; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: bn4e_branch2a/beta; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: res3b_branch2c/kernel; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: bn4e_branch2a/moving_variance; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: bn3a_branch1/gamma; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: bn2a_branch1/moving_variance; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: bn5c_branch2b/beta; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: bn3b_branch2b/gamma; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: bn4a_branch2b/moving_variance; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: bn2c_branch2c/beta; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: bn4a_branch1/moving_variance; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: bn3a_branch2b/gamma; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: bn2b_branch2b/moving_variance; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: res4b_branch2c/kernel; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: conv1/kernel; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: bn3b_branch2a/moving_mean; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: bn2c_branch2a/beta; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: bn4e_branch2a/moving_mean; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: bn5b_branch2b/moving_mean; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: bn2a_branch2a/moving_variance; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: res3c_branch2c/bias; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: bn2a_branch2b/gamma; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: bn4c_branch2b/gamma; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: bn3a_branch1/moving_variance; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: bn2a_branch2c/moving_variance; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: bn4c_branch2b/beta; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: bn2b_branch2a/gamma; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: res2b_branch2a/kernel; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: bn2a_branch2a/moving_mean; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: bn3d_branch2a/moving_variance; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: bn2b_branch2b/beta; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: bn4a_branch2a/moving_mean; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: bn2a_branch1/beta; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: bn2c_branch2c/gamma; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: bn3d_branch2c/moving_mean; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: bn3b_branch2b/moving_variance; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: bn3a_branch2c/beta; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: bn2a_branch2b/moving_variance; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: bn3a_branch2a/moving_mean; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: res4f_branch2b/bias; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: bn5a_branch1/moving_mean; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: bn3a_branch2a/beta; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: bn2b_branch2b/gamma; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: res5a_branch1/kernel; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: bn2c_branch2b/moving_mean; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: bn2c_branch2c/moving_mean; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: bn3c_branch2b/beta; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: bn2b_branch2c/beta; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: bn2a_branch1/gamma; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: bn2a_branch2c/moving_mean; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: bn4a_branch1/gamma; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: bn2c_branch2b/gamma; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: res4e_branch2c/kernel; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: bn4a_branch2b/gamma; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: res3a_branch1/bias; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: res2a_branch2a/kernel; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: bn4d_branch2a/beta; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: bn4b_branch2b/moving_mean; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: res2b_branch2c/kernel; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: bn3b_branch2b/moving_mean; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: bn2b_branch2c/gamma; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: bn4f_branch2b/beta; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: bn2b_branch2a/beta; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: bn2b_branch2b/moving_mean; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: bn3b_branch2b/beta; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: bn3a_branch2a/moving_variance; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: bn3b_branch2a/moving_variance; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: bn4c_branch2c/moving_variance; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: bn4a_branch2c/moving_variance; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: bn2a_branch2c/beta; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: bn3a_branch2c/gamma; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: bn2b_branch2c/moving_mean; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: res5a_branch2c/kernel; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: bn3a_branch2a/gamma; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: bn2a_branch2c/gamma; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: bn3c_branch2b/moving_mean; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: res4e_branch2a/kernel; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: bn4c_branch2a/beta; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: bn2b_branch2c/moving_variance; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: bn5a_branch2b/moving_variance; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: bn3d_branch2b/beta; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: bn4f_branch2a/gamma; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: bn2c_branch2a/moving_mean; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: res4c_branch2a/kernel; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: bn4b_branch2c/beta; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: bn4f_branch2a/moving_mean; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: bn3a_branch2b/beta; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: bn5a_branch2b/beta; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: bn5a_branch2a/moving_variance; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: bn3c_branch2c/moving_mean; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: conv1/bias; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: bn3a_branch2b/moving_variance; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: bn2c_branch2a/moving_variance; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: bn4e_branch2c/beta; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: res3b_branch2b/kernel; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: bn3d_branch2b/gamma; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: bn2c_branch2a/gamma; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: res5a_branch2a/kernel; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: bn2a_branch2b/moving_mean; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: bn2c_branch2b/beta; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: bn3a_branch1/beta; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: bn4a_branch2a/moving_variance; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: bn3c_branch2c/moving_variance; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: res2a_branch2b/kernel; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: bn5b_branch2a/moving_variance; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: bn3d_branch2a/moving_mean; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: bn3d_branch2b/moving_mean; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: bn4e_branch2b/moving_mean; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: res3d_branch2a/bias; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: res2c_branch2b/bias; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: bn4d_branch2c/gamma; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: res3a_branch2c/bias; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: bn3d_branch2b/moving_variance; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: bn3d_branch2c/moving_variance; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: bn3d_branch2c/gamma; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: bn4a_branch2a/gamma; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: bn4a_branch2b/beta; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: res4e_branch2c/bias; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: bn2a_branch1/moving_mean; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: bn4a_branch2b/moving_mean; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: bn4c_branch2b/moving_variance; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: bn5a_branch2a/beta; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: bn4a_branch2c/gamma; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: bn4a_branch2c/moving_mean; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: bn2a_branch2a/beta; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: bn4d_branch2a/moving_variance; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: res3a_branch1/kernel; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: bn4b_branch2a/gamma; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: bn3c_branch2a/beta; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: bn4b_branch2a/moving_mean; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: bn4a_branch1/moving_mean; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: bn4b_branch2a/moving_variance; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: bn5b_branch2c/beta; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: bn4b_branch2b/gamma; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: res5b_branch2c/bias; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: bn5c_branch2b/moving_mean; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: bn2a_branch2b/beta; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: bn4b_branch2b/moving_variance; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: bn4b_branch2c/gamma; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: res4b_branch2a/bias; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: bn4b_branch2c/moving_mean; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: bn2b_branch2a/moving_mean; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: bn2c_branch2b/moving_variance; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: bn4c_branch2a/gamma; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: bn5c_branch2c/moving_mean; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: bn4c_branch2a/moving_mean; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: bn4f_branch2b/gamma; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: res2b_branch2b/bias; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: bn4a_branch2c/beta; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: bn4c_branch2b/moving_mean; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: bn4d_branch2b/gamma; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: bn3b_branch2c/moving_variance; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: bn4d_branch2a/gamma; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: bn4a_branch1/beta; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: bn4d_branch2a/moving_mean; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: bn4d_branch2b/beta; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: bn4d_branch2c/moving_mean; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: bn4d_branch2b/moving_variance; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: bn5c_branch2a/beta; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: bn5a_branch2c/gamma; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: bn4d_branch2c/beta; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: bn4e_branch2b/beta; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: bn4e_branch2a/gamma; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: bn4a_branch2a/beta; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: bn4e_branch2b/gamma; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: res5b_branch2a/kernel; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: res5a_branch2c/bias; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: bn4e_branch2b/moving_variance; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: bn2c_branch2c/moving_variance; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: bn3d_branch2a/beta; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: bn4f_branch2b/moving_mean; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: res4b_branch2a/kernel; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: bn4e_branch2c/gamma; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: res5b_branch2c/kernel; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: res4f_branch2c/kernel; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: bn_conv1/moving_mean; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: bn4e_branch2c/moving_variance; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: bn4b_branch2a/beta; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: bn4f_branch2a/beta; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: bn4f_branch2c/gamma; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: bn3b_branch2a/gamma; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: bn3d_branch2a/gamma; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: bn4e_branch2c/moving_mean; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: bn4f_branch2a/moving_variance; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: res4e_branch2b/kernel; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: bn4f_branch2b/moving_variance; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: res4e_branch2b/bias; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: bn4f_branch2c/beta; prev_var_name: Unchanged
# INFO:tensorflow:TPU job name worker
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Saving checkpoints for 0 into gs://gs_colab/work/tutorial5/2019-05-16-15:44:07/model.ckpt.
# INFO:tensorflow:Initialized dataset iterators in 0 seconds
# INFO:tensorflow:Installing graceful shutdown hook.
# INFO:tensorflow:Creating heartbeat manager for ['/job:worker/replica:0/task:0/device:CPU:0']
# INFO:tensorflow:Configuring worker heartbeat: shutdown_mode: WAIT_FOR_COORDINATOR
#
# INFO:tensorflow:Init TPU system
# INFO:tensorflow:Initialized TPU in 13 seconds
# INFO:tensorflow:Starting infeed thread controller.
# INFO:tensorflow:Starting outfeed thread controller.
# INFO:tensorflow:Enqueue next (22) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (22) batch(es) of data from outfeed.
# INFO:tensorflow:loss = 1.4380969, step = 22
# INFO:tensorflow:Enqueue next (22) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (22) batch(es) of data from outfeed.
# INFO:tensorflow:Enqueue next (22) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (22) batch(es) of data from outfeed.
# INFO:tensorflow:Enqueue next (22) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (22) batch(es) of data from outfeed.
# INFO:tensorflow:Enqueue next (22) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (22) batch(es) of data from outfeed.
# INFO:tensorflow:Enqueue next (22) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (22) batch(es) of data from outfeed.
# INFO:tensorflow:loss = 0.979477, step = 132 (14.781 sec)
# INFO:tensorflow:global_step/sec: 7.44197
# INFO:tensorflow:examples/sec: 952.572
# INFO:tensorflow:Enqueue next (22) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (22) batch(es) of data from outfeed.
# INFO:tensorflow:Enqueue next (22) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (22) batch(es) of data from outfeed.
# INFO:tensorflow:Enqueue next (22) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (22) batch(es) of data from outfeed.
# INFO:tensorflow:Enqueue next (22) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (22) batch(es) of data from outfeed.
# INFO:tensorflow:Enqueue next (22) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (22) batch(es) of data from outfeed.
# INFO:tensorflow:loss = 0.0028290583, step = 242 (12.616 sec)
# INFO:tensorflow:global_step/sec: 8.71849
# INFO:tensorflow:examples/sec: 1115.97
# INFO:tensorflow:Saving checkpoints for 242 into gs://gs_colab/work/tutorial5/2019-05-16-15:44:07/model.ckpt.
# INFO:tensorflow:Stop infeed thread controller
# INFO:tensorflow:Shutting down InfeedController thread.
# INFO:tensorflow:InfeedController received shutdown signal, stopping.
# INFO:tensorflow:Infeed thread finished, shutting down.
# INFO:tensorflow:infeed marked as finished
# INFO:tensorflow:Stop output thread controller
# INFO:tensorflow:Shutting down OutfeedController thread.
# INFO:tensorflow:OutfeedController received shutdown signal, stopping.
# INFO:tensorflow:Outfeed thread finished, shutting down.
# INFO:tensorflow:outfeed marked as finished
# INFO:tensorflow:Shutdown TPU system.
# INFO:tensorflow:Loss for final step: 0.0028290583.
# INFO:tensorflow:training_loop marked as finished
# INFO:tensorflow:Calling model_fn.
# ERROR:tensorflow:Operation of type Placeholder (input_1) is not supported on the TPU. Execution will fail if this op is used in the graph.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2019-05-16T15:51:35Z
# INFO:tensorflow:TPU job name worker
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from gs://gs_colab/work/tutorial5/2019-05-16-15:44:07/model.ckpt-242
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Init TPU system
# INFO:tensorflow:Initialized TPU in 13 seconds
# INFO:tensorflow:Starting infeed thread controller.
# INFO:tensorflow:Starting outfeed thread controller.
# INFO:tensorflow:Initialized dataset iterators in 0 seconds
# INFO:tensorflow:Enqueue next (1) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1) batch(es) of data from outfeed.
# INFO:tensorflow:Evaluation [1/1]
# INFO:tensorflow:Stop infeed thread controller
# INFO:tensorflow:Shutting down InfeedController thread.
# INFO:tensorflow:InfeedController received shutdown signal, stopping.
# INFO:tensorflow:Infeed thread finished, shutting down.
# INFO:tensorflow:infeed marked as finished
# INFO:tensorflow:Stop output thread controller
# INFO:tensorflow:Shutting down OutfeedController thread.
# INFO:tensorflow:OutfeedController received shutdown signal, stopping.
# INFO:tensorflow:Outfeed thread finished, shutting down.
# INFO:tensorflow:outfeed marked as finished
# INFO:tensorflow:Shutdown TPU system.
# INFO:tensorflow:Finished evaluation at 2019-05-16-15:51:59
# INFO:tensorflow:Saving dict for global step 242: accuracy = 0.89972526, global_step = 242, loss = 1.337041
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 242: gs://gs_colab/work/tutorial5/2019-05-16-15:44:07/model.ckpt-242
# INFO:tensorflow:evaluation_loop marked as finished

# %%
result.append(train_eval_fold(4))
# Out:
#     <script src="/static/components/requirejs/require.js"></script>
#     <script>
#       requirejs.config({
#         paths: {
#           base: '/static/base',
#           plotly: 'https://cdn.plot.ly/plotly-1.47.1.min.js?noext',
#         },
#       });
#     </script>
# INFO:tensorflow:Calling model_fn.
# ERROR:tensorflow:Operation of type Placeholder (input_1) is not supported on the TPU. Execution will fail if this op is used in the graph.
# /usr/local/lib/python3.6/dist-packages/keras_applications/resnet50.py:265: UserWarning:
#
# The output shape of `ResNet50(include_top=False)` has been changed since Keras 2.2.0.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Warm-starting with WarmStartSettings: WarmStartSettings(ckpt_to_initialize_from='gs://gs_colab/model
4f_branch2c/moving_mean[^/]', 'bn3c_branch2a/gamma[^/]', 'bn5a_branch2c/beta[^/]', 'bn3d_branch2c/beta[^/]', 'bn4c_branch2c/gamma[^/]', 'res3c_branch2c/kernel[^/]', 'res3b_branch2c/bias[^/]', 'bn5b_branch2b/beta[^/]', 'bn3c_branch2b/gamma[^/]', 'bn4c_branch2c/beta[^/]', 'bn3c_branch2a/moving_mean[^/]', 'res4b_branch2c/bias[^/]', 'res2c_branch2b/kernel[^/]', 'bn3c_branch2b/moving_variance[^/]', 'bn5c_branch2c/moving_variance[^/]', 'bn4c_branch2c/moving_mean[^/]', 'res5a_branch2b/bias[^/]', 'bn3b_branch2c/gamma[^/]', 'bn3b_branch2a/beta[^/]', 'bn4c_branch2a/moving_variance[^/]', 'bn3c_branch2c/gamma[^/]', 'bn2a_branch2a/gamma[^/]', 'bn3a_branch2c/moving_variance[^/]', 'bn3a_branch2b/moving_mean[^/]', 'bn3c_branch2a/moving_variance[^/]', 'bn4d_branch2c/moving_variance[^/]', 'bn3b_branch2c/beta[^/]', 'bn5c_branch2a/moving_variance[^/]', 'bn4b_branch2c/moving_variance[^/]', 'bn3a_branch2c/moving_mean[^/]', 'bn2b_branch2a/moving_variance[^/]', 'bn4b_branch2b/beta[^/]', 'bn3b_branch2c/moving_mean[^/]', 'res4b_branch2b/kernel[^/]', 'bn3a_branch1/moving_mean[^/]', 'bn4d_branch2b/moving_mean[^/]', 'bn3c_branch2c/beta[^/]', 'res5c_branch2a/bias[^/]', 'res3a_branch2b/kernel[^/]', 'bn4e_branch2a/b ...
# INFO:tensorflow:Warm-starting from: ('gs://gs_colab/model/ResNet50/keras',)
# INFO:tensorflow:Warm-starting variable: res5c_branch2c/bias; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: res5c_branch2b/kernel; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: res5c_branch2b/bias; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: res5c_branch2a/kernel; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: res5a_branch2a/bias; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: res5a_branch1/bias; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: res4f_branch2c/bias; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: res4f_branch2b/kernel; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: res4f_branch2a/bias; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: res4e_branch2a/bias; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: res4d_branch2c/kernel; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: res4d_branch2c/bias; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: res4d_branch2b/kernel; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: res4d_branch2b/bias; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: res4d_branch2a/kernel; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: res4d_branch2a/bias; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: res4c_branch2c/kernel; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: res4c_branch2c/bias; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: res4c_branch2b/kernel; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: res4c_branch2b/bias; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: res4c_branch2a/bias; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: res4b_branch2b/bias; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: res4a_branch2c/kernel; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: res4a_branch2c/bias; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: res4a_branch2b/kernel; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: res4a_branch2b/bias; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: res4a_branch2a/bias; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: res4a_branch1/kernel; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: res3d_branch2c/kernel; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: res3d_branch2c/bias; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: res3d_branch2b/kernel; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: res3d_branch2b/bias; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: res3d_branch2a/kernel; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: res3c_branch2b/bias; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: res3b_branch2b/bias; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: res3b_branch2a/kernel; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: res3b_branch2a/bias; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: res3a_branch2c/kernel; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: res3a_branch2b/bias; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: res3a_branch2a/bias; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: res2c_branch2c/kernel; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: res2c_branch2c/bias; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: res3a_branch2a/kernel; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: res2c_branch2a/kernel; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: res2c_branch2a/bias; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: res2b_branch2c/bias; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: res2b_branch2a/bias; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: res2a_branch2c/kernel; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: res2a_branch2c/bias; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: res2b_branch2b/kernel; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: res2a_branch2b/bias; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: res2a_branch2a/bias; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: res2a_branch1/kernel; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: res2a_branch1/bias; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: res5b_branch2a/bias; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: global_step; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: res5b_branch2b/bias; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: bn_conv1/moving_variance; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: res3c_branch2b/kernel; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: bn_conv1/gamma; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: bn_conv1/beta; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: bn5c_branch2c/gamma; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: bn5c_branch2c/beta; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: bn5c_branch2b/moving_variance; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: bn5c_branch2b/gamma; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: res5b_branch2b/kernel; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: bn5c_branch2a/moving_mean; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: bn5c_branch2a/gamma; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: res4f_branch2a/kernel; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: bn5b_branch2c/moving_variance; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: res5a_branch2b/kernel; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: res3c_branch2a/bias; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: bn5b_branch2c/gamma; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: res4a_branch1/bias; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: bn5b_branch2b/moving_variance; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: bn5b_branch2b/gamma; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: res4a_branch2a/kernel; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: bn5b_branch2a/moving_mean; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: bn5b_branch2a/gamma; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: bn5b_branch2a/beta; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: bn5a_branch2c/moving_variance; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: bn5a_branch2c/moving_mean; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: res5c_branch2c/kernel; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: bn5a_branch2b/moving_mean; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: bn5a_branch2b/gamma; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: bn5a_branch2a/moving_mean; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: bn5a_branch2a/gamma; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: res3c_branch2a/kernel; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: bn5a_branch1/moving_variance; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: bn5b_branch2c/moving_mean; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: bn5a_branch1/gamma; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: bn5a_branch1/beta; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: bn4f_branch2c/moving_variance; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: bn4f_branch2c/moving_mean; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: bn3c_branch2a/gamma; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: bn5a_branch2c/beta; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: bn3d_branch2c/beta; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: bn4c_branch2c/gamma; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: res3c_branch2c/kernel; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: res3b_branch2c/bias; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: bn5b_branch2b/beta; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: bn3c_branch2b/gamma; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: bn4c_branch2c/beta; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: bn3c_branch2a/moving_mean; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: res4b_branch2c/bias; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: res2c_branch2b/kernel; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: bn3c_branch2b/moving_variance; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: bn5c_branch2c/moving_variance; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: bn4c_branch2c/moving_mean; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: res5a_branch2b/bias; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: bn3b_branch2c/gamma; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: bn3b_branch2a/beta; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: bn4c_branch2a/moving_variance; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: bn3c_branch2c/gamma; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: bn2a_branch2a/gamma; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: bn3a_branch2c/moving_variance; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: bn3a_branch2b/moving_mean; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: bn3c_branch2a/moving_variance; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: bn4d_branch2c/moving_variance; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: bn3b_branch2c/beta; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: bn5c_branch2a/moving_variance; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: bn4b_branch2c/moving_variance; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: bn3a_branch2c/moving_mean; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: bn2b_branch2a/moving_variance; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: bn4b_branch2b/beta; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: bn3b_branch2c/moving_mean; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: res4b_branch2b/kernel; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: bn3a_branch1/moving_mean; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: bn4d_branch2b/moving_mean; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: bn3c_branch2c/beta; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: res5c_branch2a/bias; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: res3a_branch2b/kernel; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: bn4e_branch2a/beta; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: res3b_branch2c/kernel; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: bn4e_branch2a/moving_variance; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: bn3a_branch1/gamma; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: bn2a_branch1/moving_variance; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: bn5c_branch2b/beta; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: bn3b_branch2b/gamma; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: bn4a_branch2b/moving_variance; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: bn2c_branch2c/beta; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: bn4a_branch1/moving_variance; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: bn3a_branch2b/gamma; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: bn2b_branch2b/moving_variance; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: res4b_branch2c/kernel; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: conv1/kernel; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: bn3b_branch2a/moving_mean; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: bn2c_branch2a/beta; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: bn4e_branch2a/moving_mean; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: bn5b_branch2b/moving_mean; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: bn2a_branch2a/moving_variance; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: res3c_branch2c/bias; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: bn2a_branch2b/gamma; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: bn4c_branch2b/gamma; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: bn3a_branch1/moving_variance; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: bn2a_branch2c/moving_variance; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: bn4c_branch2b/beta; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: bn2b_branch2a/gamma; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: res2b_branch2a/kernel; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: bn2a_branch2a/moving_mean; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: bn3d_branch2a/moving_variance; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: bn2b_branch2b/beta; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: bn4a_branch2a/moving_mean; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: bn2a_branch1/beta; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: bn2c_branch2c/gamma; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: bn3d_branch2c/moving_mean; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: bn3b_branch2b/moving_variance; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: bn3a_branch2c/beta; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: bn2a_branch2b/moving_variance; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: bn3a_branch2a/moving_mean; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: res4f_branch2b/bias; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: bn5a_branch1/moving_mean; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: bn3a_branch2a/beta; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: bn2b_branch2b/gamma; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: res5a_branch1/kernel; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: bn2c_branch2b/moving_mean; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: bn2c_branch2c/moving_mean; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: bn3c_branch2b/beta; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: bn2b_branch2c/beta; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: bn2a_branch1/gamma; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: bn2a_branch2c/moving_mean; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: bn4a_branch1/gamma; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: bn2c_branch2b/gamma; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: res4e_branch2c/kernel; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: bn4a_branch2b/gamma; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: res3a_branch1/bias; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: res2a_branch2a/kernel; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: bn4d_branch2a/beta; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: bn4b_branch2b/moving_mean; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: res2b_branch2c/kernel; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: bn3b_branch2b/moving_mean; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: bn2b_branch2c/gamma; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: bn4f_branch2b/beta; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: bn2b_branch2a/beta; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: bn2b_branch2b/moving_mean; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: bn3b_branch2b/beta; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: bn3a_branch2a/moving_variance; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: bn3b_branch2a/moving_variance; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: bn4c_branch2c/moving_variance; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: bn4a_branch2c/moving_variance; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: bn2a_branch2c/beta; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: bn3a_branch2c/gamma; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: bn2b_branch2c/moving_mean; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: res5a_branch2c/kernel; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: bn3a_branch2a/gamma; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: bn2a_branch2c/gamma; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: bn3c_branch2b/moving_mean; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: res4e_branch2a/kernel; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: bn4c_branch2a/beta; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: bn2b_branch2c/moving_variance; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: bn5a_branch2b/moving_variance; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: bn3d_branch2b/beta; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: bn4f_branch2a/gamma; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: bn2c_branch2a/moving_mean; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: res4c_branch2a/kernel; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: bn4b_branch2c/beta; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: bn4f_branch2a/moving_mean; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: bn3a_branch2b/beta; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: bn5a_branch2b/beta; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: bn5a_branch2a/moving_variance; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: bn3c_branch2c/moving_mean; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: conv1/bias; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: bn3a_branch2b/moving_variance; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: bn2c_branch2a/moving_variance; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: bn4e_branch2c/beta; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: res3b_branch2b/kernel; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: bn3d_branch2b/gamma; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: bn2c_branch2a/gamma; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: res5a_branch2a/kernel; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: bn2a_branch2b/moving_mean; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: bn2c_branch2b/beta; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: bn3a_branch1/beta; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: bn4a_branch2a/moving_variance; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: bn3c_branch2c/moving_variance; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: res2a_branch2b/kernel; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: bn5b_branch2a/moving_variance; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: bn3d_branch2a/moving_mean; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: bn3d_branch2b/moving_mean; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: bn4e_branch2b/moving_mean; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: res3d_branch2a/bias; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: res2c_branch2b/bias; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: bn4d_branch2c/gamma; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: res3a_branch2c/bias; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: bn3d_branch2b/moving_variance; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: bn3d_branch2c/moving_variance; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: bn3d_branch2c/gamma; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: bn4a_branch2a/gamma; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: bn4a_branch2b/beta; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: res4e_branch2c/bias; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: bn2a_branch1/moving_mean; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: bn4a_branch2b/moving_mean; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: bn4c_branch2b/moving_variance; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: bn5a_branch2a/beta; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: bn4a_branch2c/gamma; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: bn4a_branch2c/moving_mean; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: bn2a_branch2a/beta; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: bn4d_branch2a/moving_variance; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: res3a_branch1/kernel; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: bn4b_branch2a/gamma; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: bn3c_branch2a/beta; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: bn4b_branch2a/moving_mean; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: bn4a_branch1/moving_mean; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: bn4b_branch2a/moving_variance; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: bn5b_branch2c/beta; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: bn4b_branch2b/gamma; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: res5b_branch2c/bias; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: bn5c_branch2b/moving_mean; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: bn2a_branch2b/beta; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: bn4b_branch2b/moving_variance; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: bn4b_branch2c/gamma; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: res4b_branch2a/bias; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: bn4b_branch2c/moving_mean; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: bn2b_branch2a/moving_mean; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: bn2c_branch2b/moving_variance; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: bn4c_branch2a/gamma; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: bn5c_branch2c/moving_mean; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: bn4c_branch2a/moving_mean; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: bn4f_branch2b/gamma; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: res2b_branch2b/bias; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: bn4a_branch2c/beta; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: bn4c_branch2b/moving_mean; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: bn4d_branch2b/gamma; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: bn3b_branch2c/moving_variance; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: bn4d_branch2a/gamma; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: bn4a_branch1/beta; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: bn4d_branch2a/moving_mean; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: bn4d_branch2b/beta; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: bn4d_branch2c/moving_mean; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: bn4d_branch2b/moving_variance; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: bn5c_branch2a/beta; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: bn5a_branch2c/gamma; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: bn4d_branch2c/beta; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: bn4e_branch2b/beta; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: bn4e_branch2a/gamma; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: bn4a_branch2a/beta; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: bn4e_branch2b/gamma; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: res5b_branch2a/kernel; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: res5a_branch2c/bias; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: bn4e_branch2b/moving_variance; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: bn2c_branch2c/moving_variance; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: bn3d_branch2a/beta; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: bn4f_branch2b/moving_mean; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: res4b_branch2a/kernel; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: bn4e_branch2c/gamma; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: res5b_branch2c/kernel; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: res4f_branch2c/kernel; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: bn_conv1/moving_mean; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: bn4e_branch2c/moving_variance; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: bn4b_branch2a/beta; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: bn4f_branch2a/beta; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: bn4f_branch2c/gamma; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: bn3b_branch2a/gamma; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: bn3d_branch2a/gamma; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: bn4e_branch2c/moving_mean; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: bn4f_branch2a/moving_variance; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: res4e_branch2b/kernel; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: bn4f_branch2b/moving_variance; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: res4e_branch2b/bias; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: bn4f_branch2c/beta; prev_var_name: Unchanged
# INFO:tensorflow:TPU job name worker
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Saving checkpoints for 0 into gs://gs_colab/work/tutorial5/2019-05-16-15:44:07/model.ckpt.
# INFO:tensorflow:Initialized dataset iterators in 0 seconds
# INFO:tensorflow:Installing graceful shutdown hook.
# INFO:tensorflow:Creating heartbeat manager for ['/job:worker/replica:0/task:0/device:CPU:0']
# INFO:tensorflow:Configuring worker heartbeat: shutdown_mode: WAIT_FOR_COORDINATOR
#
# INFO:tensorflow:Init TPU system
# INFO:tensorflow:Initialized TPU in 13 seconds
# INFO:tensorflow:Starting infeed thread controller.
# INFO:tensorflow:Starting outfeed thread controller.
# INFO:tensorflow:Enqueue next (22) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (22) batch(es) of data from outfeed.
# INFO:tensorflow:loss = 4.3425303, step = 22
# INFO:tensorflow:Enqueue next (22) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (22) batch(es) of data from outfeed.
# INFO:tensorflow:Enqueue next (22) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (22) batch(es) of data from outfeed.
# INFO:tensorflow:Enqueue next (22) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (22) batch(es) of data from outfeed.
# INFO:tensorflow:Enqueue next (22) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (22) batch(es) of data from outfeed.
# INFO:tensorflow:Enqueue next (22) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (22) batch(es) of data from outfeed.
# INFO:tensorflow:loss = 0.18474872, step = 132 (15.737 sec)
# INFO:tensorflow:global_step/sec: 6.98998
# INFO:tensorflow:examples/sec: 894.718
# INFO:tensorflow:Enqueue next (22) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (22) batch(es) of data from outfeed.
# INFO:tensorflow:Enqueue next (22) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (22) batch(es) of data from outfeed.
# INFO:tensorflow:Enqueue next (22) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (22) batch(es) of data from outfeed.
# INFO:tensorflow:Enqueue next (22) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (22) batch(es) of data from outfeed.
# INFO:tensorflow:Enqueue next (22) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (22) batch(es) of data from outfeed.
# INFO:tensorflow:loss = 0.0065047974, step = 242 (12.391 sec)
# INFO:tensorflow:global_step/sec: 8.87753
# INFO:tensorflow:examples/sec: 1136.32
# INFO:tensorflow:Saving checkpoints for 242 into gs://gs_colab/work/tutorial5/2019-05-16-15:44:07/model.ckpt.
# INFO:tensorflow:Stop infeed thread controller
# INFO:tensorflow:Shutting down InfeedController thread.
# INFO:tensorflow:InfeedController received shutdown signal, stopping.
# INFO:tensorflow:Infeed thread finished, shutting down.
# INFO:tensorflow:infeed marked as finished
# INFO:tensorflow:Stop output thread controller
# INFO:tensorflow:Shutting down OutfeedController thread.
# INFO:tensorflow:OutfeedController received shutdown signal, stopping.
# INFO:tensorflow:Outfeed thread finished, shutting down.
# INFO:tensorflow:outfeed marked as finished
# INFO:tensorflow:Shutdown TPU system.
# INFO:tensorflow:Loss for final step: 0.0065047974.
# INFO:tensorflow:training_loop marked as finished
# INFO:tensorflow:Calling model_fn.
# ERROR:tensorflow:Operation of type Placeholder (input_1) is not supported on the TPU. Execution will fail if this op is used in the graph.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2019-05-16T15:53:37Z
# INFO:tensorflow:TPU job name worker
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from gs://gs_colab/work/tutorial5/2019-05-16-15:44:07/model.ckpt-242
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Init TPU system
# INFO:tensorflow:Initialized TPU in 12 seconds
# INFO:tensorflow:Starting infeed thread controller.
# INFO:tensorflow:Starting outfeed thread controller.
# INFO:tensorflow:Initialized dataset iterators in 0 seconds
# INFO:tensorflow:Enqueue next (1) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1) batch(es) of data from outfeed.
# INFO:tensorflow:Evaluation [1/1]
# INFO:tensorflow:Stop infeed thread controller
# INFO:tensorflow:Shutting down InfeedController thread.
# INFO:tensorflow:InfeedController received shutdown signal, stopping.
# INFO:tensorflow:Infeed thread finished, shutting down.
# INFO:tensorflow:infeed marked as finished
# INFO:tensorflow:Stop output thread controller
# INFO:tensorflow:Shutting down OutfeedController thread.
# INFO:tensorflow:OutfeedController received shutdown signal, stopping.
# INFO:tensorflow:Outfeed thread finished, shutting down.
# INFO:tensorflow:outfeed marked as finished
# INFO:tensorflow:Shutdown TPU system.
# INFO:tensorflow:Finished evaluation at 2019-05-16-15:54:01
# INFO:tensorflow:Saving dict for global step 242: accuracy = 0.9010989, global_step = 242, loss = 1.0957325
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 242: gs://gs_colab/work/tutorial5/2019-05-16-15:44:07/model.ckpt-242
# INFO:tensorflow:evaluation_loop marked as finished

# %%
acc = [res['accuracy'] for res in result]
loss = [res['loss'] for res in result]

print('accuracy:', np.mean(acc), '+/-', np.std(acc))
print('loss:', np.mean(loss), '+/-', np.std(loss))
# Out:
#     <script src="/static/components/requirejs/require.js"></script>
#     <script>
#       requirejs.config({
#         paths: {
#           base: '/static/base',
#           plotly: 'https://cdn.plot.ly/plotly-1.47.1.min.js?noext',
#         },
#       });
#     </script>
# accuracy: 0.90521973 +/- 0.0052844575
# loss: 1.3722885 +/- 0.1595051
